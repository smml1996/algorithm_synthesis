# %%
import os, sys
sys.path.append(os.getcwd()+"/../..")
sys.path.append(os.getcwd()+"/..")
from bit_flip_experiments import *
import pandas as pd
from utils import *
from game import *
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from notebook_utils import *

# %%
Precision.PRECISION = 10
Precision.update_threshold()
# generate_all_lambdas_file()
comments = get_different_algorithms_data(instruction_set="", serialize_dump=False)
# Out:
# ['fake_athens', 'fake_belem', 'fake_tenerife', 'fake_lima', 'fake_rome', 'fake_manila', 'fake_santiago', 'fake_bogota', 'fake_ourense', 'fake_yorktown', 'fake_essex', 'fake_vigo', 'fake_burlington', 'fake_quito', 'fake_london', 'fake_jakarta', 'fake_oslo', 'fake_perth', 'fake_lagos', 'fake_nairobi', 'fake_casablanca', 'fake_melbourne', 'fake_guadalupe', 'fake_tokyo', 'fake_poughkeepsie', 'fake_johannesburg', 'fake_boeblingen', 'fake_almaden', 'fake_singapore', 'fake_mumbai', 'fake_paris', 'fake_auckland', 'fake_kolkata', 'fake_toronto', 'fake_montreal', 'fake_sydney', 'fake_cairo', 'fake_hanoi', 'fake_geneva', 'fake_cambridge', 'fake_rochester', 'fake_brooklyn', 'fake_manhattan', 'fake_washington']

# %%
check_backends_vs_file(comments, exp_index="")

# %%
algs_union = dict()
for horizon in range(4, 8):
    algs_union[horizon] = dict()
    for alg_index in range(get_num_algorithms(horizon)):
        algs_union[horizon][alg_index] = alg_index

# horizon 5
algs_union[5][4] = 0
algs_union[5][3] = 1
algs_union[5][5] = 2
algs_union[5][8] = 2

# horizon 6
algs_union[6][1] = 0
algs_union[6][4] = 2
algs_union[6][7] = 6

# horizon 7
algs_union[7][6] = 0
algs_union[7][4] = 1
algs_union[7][5] = 1
algs_union[7][7] = 1
algs_union[7][3] = 2
algs_union[7][8] = 2
algs_union[7][13] = 2

# %% [markdown]
# # Horizon 4

# %%
df4 = get_horizon_df(4, comments)

# %%
get_similar_algorithms(4, 0)
print()
get_similar_algorithms(4, 1)
# Out:
# difference of algorithm=0 at horizon=4
# diff with alg. 0: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 1: max=0.9764866960316393 min=0.0008555360570222104 std=0.19225476654028606 avg=0.8258572130313863
#
# difference of algorithm=1 at horizon=4
# diff with alg. 0: max=0.9764866960316393 min=0.0008555360570222104 std=0.19225476654028606 avg=0.8258572130313863
# diff with alg. 1: max=0.0 min=0.0 std=0.0 avg=0.0

# %%
result = get_df_horizon_describe(df4)
result.to_csv(DIR_PREFIX + "analysis_results/h4_programs.csv")
result
# Out:
#                           value                                        \
#                           count      mean       std     min       25%
# program variable
# 0       accum_prob        221.0  0.942742  0.075105  0.5965  0.931000
#         couplers_success  221.0  0.966928  0.094398  0.0000  0.968500
#         success0          221.0  0.955697  0.077628  0.3520  0.954000
#         success1          221.0  0.929787  0.101882  0.2590  0.921000
#         success_diff      221.0  0.025910  0.101237 -0.5180  0.002000
# 1       accum_prob          4.0  0.817625  0.166986  0.6100  0.718750
#         couplers_success    4.0  0.476125  0.014168  0.4565  0.471875
#         success0            4.0  0.852500  0.108285  0.7190  0.787250
#         success1            4.0  0.782750  0.262196  0.4100  0.695750
#         success_diff        4.0  0.069750  0.222280 -0.0720 -0.055500
#
#
#                               50%       75%    max
# program variable
# 0       accum_prob        0.97050  0.985000  0.997
#         couplers_success  0.98150  0.989000  0.994
#         success0          0.98500  0.992000  0.998
#         success1          0.96100  0.981000  0.996
#         success_diff      0.01400  0.032000  0.675
# 1       accum_prob        0.85025  0.949125  0.960
#         couplers_success  0.47900  0.483250  0.490
#         success0          0.87250  0.937750  0.946
#         success1          0.86800  0.955000  0.985
#         success_diff     -0.02450  0.100750  0.400

# %% [markdown]
# # Horizon 5

# %%
df5 = get_horizon_df(5, comments)

# %%
for i in range(get_num_algorithms(5)):
    get_similar_algorithms(5, i)
    print("-----------")
    print()
# Out:
# difference of algorithm=0 at horizon=5
# diff with alg. 0: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 1: max=0.1571680183285752 min=0.0 std=0.0323642972916912 avg=0.025921945825340582
# diff with alg. 2: max=0.07942350725747804 min=0.0 std=0.016506285201825496 avg=0.013163218448264149
# diff with alg. 3: max=0.15884839950654894 min=0.0 std=0.03301272207186491 avg=0.026326443336813523
# diff with alg. 4: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 5: max=0.07942419975327442 min=0.0 std=0.01650636103593245 avg=0.013163221668406753
# diff with alg. 6: max=0.9794161561197342 min=0.001432680681089371 std=0.19768986659619736 avg=0.8417612469502161
# diff with alg. 7: max=0.9764866960316393 min=0.0008555360570222104 std=0.19225476654028606 avg=0.8258572130313863
# diff with alg. 8: max=0.07942350725747804 min=0.0 std=0.016506285201825496 avg=0.013163218448264149
# -----------
#
# difference of algorithm=1 at horizon=5
# diff with alg. 0: max=0.1571680183285752 min=0.0 std=0.0323642972916912 avg=0.025921945825340582
# diff with alg. 1: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 2: max=0.07774451107109714 min=6.75375322334304e-09 std=0.01586203486068076 avg=0.012759163002491284
# diff with alg. 3: max=0.006688776773541405 min=0.0 std=0.0008353271220498948 avg=0.00040451141138150935
# diff with alg. 4: max=0.1571680183285752 min=0.0 std=0.0323642972916912 avg=0.025921945825340582
# diff with alg. 5: max=0.07774381857530077 min=4.753924809364207e-09 std=0.015862033593309555 avg=0.012759064960426099
# diff with alg. 6: max=0.9764974054603801 min=0.0011632531826655246 std=0.19217791191000994 avg=0.8261047008903643
# diff with alg. 7: max=0.9754675385026699 min=0.0005861085585983639 std=0.194464424254383 avg=0.8102006669715345
# diff with alg. 8: max=0.07774451107109714 min=6.75375322334304e-09 std=0.01586203486068076 avg=0.012759163002491284
# -----------
#
# difference of algorithm=2 at horizon=5
# diff with alg. 0: max=0.07942350725747804 min=0.0 std=0.016506285201825496 avg=0.013163218448264149
# diff with alg. 1: max=0.07774451107109714 min=6.75375322334304e-09 std=0.01586203486068076 avg=0.012759163002491284
# diff with alg. 2: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 3: max=0.0794248922490709 min=0.0 std=0.016506364529610486 avg=0.013163315642049167
# diff with alg. 4: max=0.07942350725747804 min=0.0 std=0.016506285201825496 avg=0.013163218448264149
# diff with alg. 5: max=9.869654327143706e-07 min=0.0 std=4.4270684359192696e-07 avg=5.852439761931826e-07
# diff with alg. 6: max=0.9779514260756867 min=0.0011440414511779684 std=0.1940080416899959 avg=0.8338092801775503
# diff with alg. 7: max=0.9751771413838163 min=0.0005669432278988529 std=0.19248301666443665 avg=0.8179052462587204
# diff with alg. 8: max=0.0 min=0.0 std=0.0 avg=0.0
# -----------
#
# difference of algorithm=3 at horizon=5
# diff with alg. 0: max=0.15884839950654894 min=0.0 std=0.03301272207186491 avg=0.026326443336813523
# diff with alg. 1: max=0.006688776773541405 min=0.0 std=0.0008353271220498948 avg=0.00040451141138150935
# diff with alg. 2: max=0.0794248922490709 min=0.0 std=0.016506364529610486 avg=0.013163315642049167
# diff with alg. 3: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 4: max=0.15884839950654894 min=0.0 std=0.03301272207186491 avg=0.026326443336813523
# diff with alg. 5: max=0.07942419975327453 min=0.0 std=0.016506361035932463 avg=0.013163221668406765
# diff with alg. 6: max=0.9764866960316393 min=0.0008555360570221548 std=0.19225476654028606 avg=0.8258572130313864
# diff with alg. 7: max=0.9754696067866107 min=0.00027839143295499413 std=0.19468557585254284 avg=0.8099531791125565
# diff with alg. 8: max=0.0794248922490709 min=0.0 std=0.016506364529610486 avg=0.013163315642049167
# -----------
#
# difference of algorithm=4 at horizon=5
# diff with alg. 0: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 1: max=0.1571680183285752 min=0.0 std=0.0323642972916912 avg=0.025921945825340582
# diff with alg. 2: max=0.07942350725747804 min=0.0 std=0.016506285201825496 avg=0.013163218448264149
# diff with alg. 3: max=0.15884839950654894 min=0.0 std=0.03301272207186491 avg=0.026326443336813523
# diff with alg. 4: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 5: max=0.07942419975327442 min=0.0 std=0.01650636103593245 avg=0.013163221668406753
# diff with alg. 6: max=0.9794161561197342 min=0.001432680681089371 std=0.19768986659619736 avg=0.8417612469502161
# diff with alg. 7: max=0.9764866960316393 min=0.0008555360570222104 std=0.19225476654028606 avg=0.8258572130313863
# diff with alg. 8: max=0.07942350725747804 min=0.0 std=0.016506285201825496 avg=0.013163218448264149
# -----------
#
# difference of algorithm=5 at horizon=5
# diff with alg. 0: max=0.07942419975327442 min=0.0 std=0.01650636103593245 avg=0.013163221668406753
# diff with alg. 1: max=0.07774381857530077 min=4.753924809364207e-09 std=0.015862033593309555 avg=0.012759064960426099
# diff with alg. 2: max=9.869654327143706e-07 min=0.0 std=4.4270684359192696e-07 avg=5.852439761931826e-07
# diff with alg. 3: max=0.07942419975327453 min=0.0 std=0.016506361035932463 avg=0.013163221668406765
# diff with alg. 4: max=0.07942419975327442 min=0.0 std=0.01650636103593245 avg=0.013163221668406753
# diff with alg. 5: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 6: max=0.9779514260756867 min=0.001144108369055763 std=0.1940079728272108 avg=0.8338092299908012
# diff with alg. 7: max=0.9751771413838163 min=0.0005669637449886022 std=0.1924829565588359 avg=0.8179051960719713
# diff with alg. 8: max=9.869654327143706e-07 min=0.0 std=4.4270684359192696e-07 avg=5.852439761931826e-07
# -----------
#
# difference of algorithm=6 at horizon=5
# diff with alg. 0: max=0.9794161561197342 min=0.001432680681089371 std=0.19768986659619736 avg=0.8417612469502161
# diff with alg. 1: max=0.9764974054603801 min=0.0011632531826655246 std=0.19217791191000994 avg=0.8261047008903643
# diff with alg. 2: max=0.9779514260756867 min=0.0011440414511779684 std=0.1940080416899959 avg=0.8338092801775503
# diff with alg. 3: max=0.9764866960316393 min=0.0008555360570221548 std=0.19225476654028606 avg=0.8258572130313864
# diff with alg. 4: max=0.9794161561197342 min=0.001432680681089371 std=0.19768986659619736 avg=0.8417612469502161
# diff with alg. 5: max=0.9779514260756867 min=0.001144108369055763 std=0.1940079728272108 avg=0.8338092299908012
# diff with alg. 6: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 7: max=0.15884839950654903 min=0.0 std=0.03301272207186491 avg=0.026326443336813523
# diff with alg. 8: max=0.9779514260756867 min=0.0011440414511779684 std=0.1940080416899959 avg=0.8338092801775503
# -----------
#
# difference of algorithm=7 at horizon=5
# diff with alg. 0: max=0.9764866960316393 min=0.0008555360570222104 std=0.19225476654028606 avg=0.8258572130313863
# diff with alg. 1: max=0.9754675385026699 min=0.0005861085585983639 std=0.194464424254383 avg=0.8102006669715345
# diff with alg. 2: max=0.9751771413838163 min=0.0005669432278988529 std=0.19248301666443665 avg=0.8179052462587204
# diff with alg. 3: max=0.9754696067866107 min=0.00027839143295499413 std=0.19468557585254284 avg=0.8099531791125565
# diff with alg. 4: max=0.9764866960316393 min=0.0008555360570222104 std=0.19225476654028606 avg=0.8258572130313863
# diff with alg. 5: max=0.9751771413838163 min=0.0005669637449886022 std=0.1924829565588359 avg=0.8179051960719713
# diff with alg. 6: max=0.15884839950654903 min=0.0 std=0.03301272207186491 avg=0.026326443336813523
# diff with alg. 7: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 8: max=0.9751771413838163 min=0.0005669432278988529 std=0.19248301666443665 avg=0.8179052462587204
# -----------
#
# difference of algorithm=8 at horizon=5
# diff with alg. 0: max=0.07942350725747804 min=0.0 std=0.016506285201825496 avg=0.013163218448264149
# diff with alg. 1: max=0.07774451107109714 min=6.75375322334304e-09 std=0.01586203486068076 avg=0.012759163002491284
# diff with alg. 2: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 3: max=0.0794248922490709 min=0.0 std=0.016506364529610486 avg=0.013163315642049167
# diff with alg. 4: max=0.07942350725747804 min=0.0 std=0.016506285201825496 avg=0.013163218448264149
# diff with alg. 5: max=9.869654327143706e-07 min=0.0 std=4.4270684359192696e-07 avg=5.852439761931826e-07
# diff with alg. 6: max=0.9779514260756867 min=0.0011440414511779684 std=0.1940080416899959 avg=0.8338092801775503
# diff with alg. 7: max=0.9751771413838163 min=0.0005669432278988529 std=0.19248301666443665 avg=0.8179052462587204
# diff with alg. 8: max=0.0 min=0.0 std=0.0 avg=0.0
# -----------

# %% [markdown]
# Algorithms groups
# - 0 = 4 // searches for first 1
# - 1 = 3 /// Trust on 0
# - 2 = 5 = 8 // only 1 measurement is enough
# - 6
# - 7
#
# Note: Algorithm 0 is the traditional algorithm

# %%
df5.loc[df5["program"] == 4, "program"] = 0
df5.loc[df5["program"] == 3, "program"] = 1
df5.loc[df5["program"] == 5, "program"] = 2
df5.loc[df5["program"] == 8, "program"] = 2

# %%
result = get_df_horizon_describe(df5)
result.to_csv(DIR_PREFIX + "analysis_results/h5_programs.csv")

# %%
result
# Out:
#                           value                                        \
#                           count      mean       std     min       25%
# program variable
# 0       accum_prob        170.0  0.949900  0.068475  0.5965  0.942750
#         couplers_success  170.0  0.963229  0.107013  0.0000  0.966000
#         success0          170.0  0.973365  0.039405  0.6240  0.971000
#         success1          170.0  0.926435  0.110676  0.2590  0.922250
#         success_diff      170.0  0.046929  0.094067  0.0000  0.009000
# 1       accum_prob         43.0  0.913535  0.092997  0.6110  0.878250
#         couplers_success   43.0  0.979151  0.017173  0.9225  0.972750
#         success0           43.0  0.887349  0.135324  0.3520  0.836000
#         success1           43.0  0.939721  0.062684  0.7660  0.902500
#         success_diff       43.0 -0.052372  0.099448 -0.5180 -0.076500
# 2       accum_prob          8.0  0.947625  0.075352  0.7940  0.955000
#         couplers_success    8.0  0.979812  0.019274  0.9345  0.979875
#         success0            8.0  0.947625  0.075352  0.7940  0.955000
#         success1            8.0  0.947625  0.075352  0.7940  0.955000
#         success_diff        8.0  0.000000  0.000000  0.0000  0.000000
# 6       accum_prob          2.0  0.777750  0.237234  0.6100  0.693875
#         couplers_success    2.0  0.479000  0.002828  0.4770  0.478000
#         success0            2.0  0.878000  0.096167  0.8100  0.844000
#         success1            2.0  0.677500  0.378302  0.4100  0.543750
#         success_diff        2.0  0.200500  0.282136  0.0010  0.100750
# 7       accum_prob          2.0  0.857500  0.144957  0.7550  0.806250
#         couplers_success    2.0  0.473250  0.023688  0.4565  0.464875
#         success0            2.0  0.827000  0.152735  0.7190  0.773000
#         success1            2.0  0.888000  0.137179  0.7910  0.839500
#         success_diff        2.0 -0.061000  0.015556 -0.0720 -0.066500
#
#
#                               50%       75%     max
# program variable
# 0       accum_prob        0.97100  0.984500  0.9970
#         couplers_success  0.98075  0.988000  0.9930
#         success0          0.98800  0.994000  0.9980
#         success1          0.96000  0.975750  0.9960
#         success_diff      0.02000  0.042500  0.6750
# 1       accum_prob        0.95700  0.983000  0.9945
#         couplers_success  0.98700  0.990250  0.9940
#         success0          0.95300  0.981500  0.9940
#         success1          0.96400  0.984000  0.9950
#         success_diff     -0.00400  0.000000  0.0000
# 2       accum_prob        0.98600  0.987250  0.9900
#         couplers_success  0.98650  0.990125  0.9940
#         success0          0.98600  0.987250  0.9900
#         success1          0.98600  0.987250  0.9900
#         success_diff      0.00000  0.000000  0.0000
# 6       accum_prob        0.77775  0.861625  0.9455
#         couplers_success  0.47900  0.480000  0.4810
#         success0          0.87800  0.912000  0.9460
#         success1          0.67750  0.811250  0.9450
#         success_diff      0.20050  0.300250  0.4000
# 7       accum_prob        0.85750  0.908750  0.9600
#         couplers_success  0.47325  0.481625  0.4900
#         success0          0.82700  0.881000  0.9350
#         success1          0.88800  0.936500  0.9850
#         success_diff     -0.06100 -0.055500 -0.0500

# %% [markdown]
# - success_diff for algorithm 2 is 0.0
# - couplers_success is low in algorithms 6 and 7
# - success_diff has different signs for algorithms 6 and 7
# - success_diff has different signs for algorithms 0 and 1

# %% [markdown]
# # Horizon 6

# %%
df6 = get_horizon_df(6, comments)

# %%
for i in range(get_num_algorithms(6)):
    get_similar_algorithms(6, i)
    print("-----------")
    print()
# Out:
# difference of algorithm=0 at horizon=6
# diff with alg. 0: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 1: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 2: max=0.20226164443937833 min=0.000561871262217295 std=0.04202567367174439 avg=0.034789519884806885
# diff with alg. 3: max=0.19344580254767096 min=0.0003037740413485146 std=0.043078816889799657 avg=0.0574617619114374
# diff with alg. 4: max=0.20226164443937833 min=0.000561871262217295 std=0.04202567367174439 avg=0.034789519884806885
# diff with alg. 5: max=0.9807709142320745 min=0.0012453663828386197 std=0.19238909825759298 avg=0.8526478512545076
# diff with alg. 6: max=0.9859112237228445 min=0.000683423488086421 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 7: max=0.9859112237228445 min=0.000683423488086421 std=0.1826384858990916 avg=0.8853076641673818
# -----------
#
# difference of algorithm=1 at horizon=6
# diff with alg. 0: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 1: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 2: max=0.20226164443937833 min=0.000561871262217295 std=0.04202567367174439 avg=0.034789519884806885
# diff with alg. 3: max=0.19344580254767096 min=0.0003037740413485146 std=0.043078816889799657 avg=0.0574617619114374
# diff with alg. 4: max=0.20226164443937833 min=0.000561871262217295 std=0.04202567367174439 avg=0.034789519884806885
# diff with alg. 5: max=0.9807709142320745 min=0.0012453663828386197 std=0.19238909825759298 avg=0.8526478512545076
# diff with alg. 6: max=0.9859112237228445 min=0.000683423488086421 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 7: max=0.9859112237228445 min=0.000683423488086421 std=0.1826384858990916 avg=0.8853076641673818
# -----------
#
# difference of algorithm=2 at horizon=6
# diff with alg. 0: max=0.20226164443937833 min=0.000561871262217295 std=0.04202567367174439 avg=0.034789519884806885
# diff with alg. 1: max=0.20226164443937833 min=0.000561871262217295 std=0.04202567367174439 avg=0.034789519884806885
# diff with alg. 2: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 3: max=0.23827259925982347 min=0.0 std=0.049519083107797374 avg=0.03948966500522028
# diff with alg. 4: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 5: max=0.9767066398950534 min=0.0018073092775908184 std=0.2109263446063047 avg=0.8199880383416333
# diff with alg. 6: max=0.9807709142320745 min=0.0012453663828386197 std=0.19238909825759298 avg=0.8526478512545076
# diff with alg. 7: max=0.9807709142320745 min=0.0012453663828386197 std=0.19238909825759298 avg=0.8526478512545076
# -----------
#
# difference of algorithm=3 at horizon=6
# diff with alg. 0: max=0.19344580254767096 min=0.0003037740413485146 std=0.043078816889799657 avg=0.0574617619114374
# diff with alg. 1: max=0.19344580254767096 min=0.0003037740413485146 std=0.043078816889799657 avg=0.0574617619114374
# diff with alg. 2: max=0.23827259925982347 min=0.0 std=0.049519083107797374 avg=0.03948966500522028
# diff with alg. 3: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 4: max=0.23827259925982347 min=0.0 std=0.049519083107797374 avg=0.03948966500522028
# diff with alg. 5: max=0.972312449762911 min=0.0009415923414901051 std=0.20049741668125118 avg=0.7961319874633884
# diff with alg. 6: max=0.9778929946118577 min=0.00037964944673790635 std=0.1900303326344075 avg=0.8287918003762629
# diff with alg. 7: max=0.9778929946118577 min=0.00037964944673790635 std=0.1900303326344075 avg=0.8287918003762629
# -----------
#
# difference of algorithm=4 at horizon=6
# diff with alg. 0: max=0.20226164443937833 min=0.000561871262217295 std=0.04202567367174439 avg=0.034789519884806885
# diff with alg. 1: max=0.20226164443937833 min=0.000561871262217295 std=0.04202567367174439 avg=0.034789519884806885
# diff with alg. 2: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 3: max=0.23827259925982347 min=0.0 std=0.049519083107797374 avg=0.03948966500522028
# diff with alg. 4: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 5: max=0.9767066398950534 min=0.0018073092775908184 std=0.2109263446063047 avg=0.8199880383416333
# diff with alg. 6: max=0.9807709142320745 min=0.0012453663828386197 std=0.19238909825759298 avg=0.8526478512545076
# diff with alg. 7: max=0.9807709142320745 min=0.0012453663828386197 std=0.19238909825759298 avg=0.8526478512545076
# -----------
#
# difference of algorithm=5 at horizon=6
# diff with alg. 0: max=0.9807709142320745 min=0.0012453663828386197 std=0.19238909825759298 avg=0.8526478512545076
# diff with alg. 1: max=0.9807709142320745 min=0.0012453663828386197 std=0.19238909825759298 avg=0.8526478512545076
# diff with alg. 2: max=0.9767066398950534 min=0.0018073092775908184 std=0.2109263446063047 avg=0.8199880383416333
# diff with alg. 3: max=0.972312449762911 min=0.0009415923414901051 std=0.20049741668125118 avg=0.7961319874633884
# diff with alg. 4: max=0.9767066398950534 min=0.0018073092775908184 std=0.2109263446063047 avg=0.8199880383416333
# diff with alg. 5: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 6: max=0.20226164443937839 min=0.000561871262217295 std=0.042025673671744396 avg=0.03478951988480689
# diff with alg. 7: max=0.20226164443937839 min=0.000561871262217295 std=0.042025673671744396 avg=0.03478951988480689
# -----------
#
# difference of algorithm=6 at horizon=6
# diff with alg. 0: max=0.9859112237228445 min=0.000683423488086421 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 1: max=0.9859112237228445 min=0.000683423488086421 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 2: max=0.9807709142320745 min=0.0012453663828386197 std=0.19238909825759298 avg=0.8526478512545076
# diff with alg. 3: max=0.9778929946118577 min=0.00037964944673790635 std=0.1900303326344075 avg=0.8287918003762629
# diff with alg. 4: max=0.9807709142320745 min=0.0012453663828386197 std=0.19238909825759298 avg=0.8526478512545076
# diff with alg. 5: max=0.20226164443937839 min=0.000561871262217295 std=0.042025673671744396 avg=0.03478951988480689
# diff with alg. 6: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 7: max=0.0 min=0.0 std=0.0 avg=0.0
# -----------
#
# difference of algorithm=7 at horizon=6
# diff with alg. 0: max=0.9859112237228445 min=0.000683423488086421 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 1: max=0.9859112237228445 min=0.000683423488086421 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 2: max=0.9807709142320745 min=0.0012453663828386197 std=0.19238909825759298 avg=0.8526478512545076
# diff with alg. 3: max=0.9778929946118577 min=0.00037964944673790635 std=0.1900303326344075 avg=0.8287918003762629
# diff with alg. 4: max=0.9807709142320745 min=0.0012453663828386197 std=0.19238909825759298 avg=0.8526478512545076
# diff with alg. 5: max=0.20226164443937839 min=0.000561871262217295 std=0.042025673671744396 avg=0.03478951988480689
# diff with alg. 6: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 7: max=0.0 min=0.0 std=0.0 avg=0.0
# -----------

# %% [markdown]
# - 0 = 1
# - 2 = 4 // flip on first encounter with 1
# - 3 // ends on first encounter with 0
# - 5
# - 6 = 7
#
# Note: Algorithm 0 is the traditional algorithm

# %%
df6.loc[df6["program"] == 1, "program"] = 0

df6.loc[df6["program"] == 4, "program"] = 2
df6.loc[df6["program"] == 7, "program"] = 6

# %%
result = get_df_horizon_describe(df6)
result.to_csv(DIR_PREFIX + "analysis_results/h6_programs.csv")

# %%
result
# Out:
#                           value                                        \
#                           count      mean       std     min       25%
# program variable
# 0       accum_prob        207.0  0.953502  0.055348  0.6195  0.947500
#         couplers_success  207.0  0.977024  0.016879  0.8920  0.971000
#         success0          207.0  0.962005  0.061807  0.6240  0.959000
#         success1          207.0  0.945000  0.056724  0.6150  0.930500
#         success_diff      207.0  0.017005  0.042680 -0.1680  0.002000
# 2       accum_prob         10.0  0.782200  0.143755  0.5965  0.625000
#         couplers_success   10.0  0.758050  0.400534  0.0000  0.907375
#         success0           10.0  0.950400  0.043719  0.8540  0.934000
#         success1           10.0  0.614000  0.251454  0.2590  0.381000
#         success_diff       10.0  0.336400  0.218217  0.1370  0.144500
# 3       accum_prob          4.0  0.787250  0.123137  0.6110  0.762875
#         couplers_success    4.0  0.966625  0.012492  0.9485  0.964250
#         success0            4.0  0.642500  0.200600  0.3520  0.610750
#         success1            4.0  0.932000  0.046705  0.8700  0.915000
#         success_diff        4.0 -0.289500  0.155539 -0.5180 -0.308000
# 5       accum_prob          1.0  0.610000       NaN  0.6100  0.610000
#         couplers_success    1.0  0.477000       NaN  0.4770  0.477000
#         success0            1.0  0.810000       NaN  0.8100  0.810000
#         success1            1.0  0.410000       NaN  0.4100  0.410000
#         success_diff        1.0  0.400000       NaN  0.4000  0.400000
# 6       accum_prob          3.0  0.886833  0.114401  0.7550  0.850250
#         couplers_success    3.0  0.475833  0.017337  0.4565  0.468750
#         success0            3.0  0.866667  0.128001  0.7190  0.827000
#         success1            3.0  0.907000  0.102430  0.7910  0.868000
#         success_diff        3.0 -0.040333  0.037448 -0.0720 -0.061000
#
#
#                               50%       75%     max
# program variable
# 0       accum_prob        0.97250  0.985500  0.9970
#         couplers_success  0.98250  0.989000  0.9940
#         success0          0.98600  0.992000  0.9980
#         success1          0.96400  0.982000  0.9960
#         success_diff      0.01400  0.028500  0.2100
# 2       accum_prob        0.82700  0.916375  0.9230
#         couplers_success  0.93150  0.969250  0.9835
#         success0          0.95600  0.987000  0.9930
#         success1          0.69800  0.845250  0.8530
#         success_diff      0.25800  0.488000  0.6750
# 3       accum_prob        0.82025  0.844625  0.8975
#         couplers_success  0.97050  0.972875  0.9770
#         success0          0.70250  0.734250  0.8130
#         success1          0.93800  0.955000  0.9820
#         success_diff     -0.23550 -0.217000 -0.1690
# 5       accum_prob        0.61000  0.610000  0.6100
#         couplers_success  0.47700  0.477000  0.4770
#         success0          0.81000  0.810000  0.8100
#         success1          0.41000  0.410000  0.4100
#         success_diff      0.40000  0.400000  0.4000
# 6       accum_prob        0.94550  0.952750  0.9600
#         couplers_success  0.48100  0.485500  0.4900
#         success0          0.93500  0.940500  0.9460
#         success1          0.94500  0.965000  0.9850
#         success_diff     -0.05000 -0.024500  0.0010

# %% [markdown]
# # Horizon 7

# %%
df7 = get_horizon_df(7, comments)

# %%
for i in range(get_num_algorithms(7)):
    get_similar_algorithms(7, i)
    print("-----------")
    print()
# Out:
# difference of algorithm=0 at horizon=7
# diff with alg. 0: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 1: max=0.15493713538416176 min=0.0 std=0.024637496259428862 avg=0.011586586315265745
# diff with alg. 2: max=0.07829610973648948 min=0.0 std=0.012580966423502121 avg=0.005903053601253555
# diff with alg. 3: max=0.07829610973648948 min=0.0 std=0.012580966423502121 avg=0.005903053601253555
# diff with alg. 4: max=0.1524733861551929 min=0.0 std=0.02449659929754315 avg=0.011514054553013261
# diff with alg. 5: max=0.15659366543334108 min=0.0 std=0.02516205788848186 avg=0.011806110129786333
# diff with alg. 6: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 7: max=0.15659366543334108 min=0.0 std=0.02516205788848186 avg=0.011806110129786333
# diff with alg. 8: max=0.07829683271667054 min=0.0 std=0.012581028944240928 avg=0.005903055064893167
# diff with alg. 9: max=0.9859112239940417 min=0.001123051931834429 std=0.18420600774350543 avg=0.8893479475458104
# diff with alg. 10: max=0.29214188047386014 min=0.0005515748697140221 std=0.062104293185226575 avg=0.07913599440243672
# diff with alg. 11: max=0.19554853172498599 min=0.00045607582262130464 std=0.0489515343690749 avg=0.04635139587352872
# diff with alg. 12: max=0.9859112237228445 min=0.0006834234880863654 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 13: max=0.07829610973648948 min=0.0 std=0.012580966423502121 avg=0.005903053601253555
# -----------
#
# difference of algorithm=1 at horizon=7
# diff with alg. 0: max=0.15493713538416176 min=0.0 std=0.024637496259428862 avg=0.011586586315265745
# diff with alg. 1: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 2: max=0.07664102564767228 min=1.3683976174405643e-10 std=0.012058903743526604 avg=0.00568389189506592
# diff with alg. 3: max=0.07664102564767228 min=1.3683976174405643e-10 std=0.012058903743526604 avg=0.00568389189506592
# diff with alg. 4: max=0.0033684539023393634 min=0.0 std=0.00037106335336643223 avg=0.00010576882479823037
# diff with alg. 5: max=0.005073972284873052 min=0.0 std=0.0006306791513843534 avg=0.00021952839054565032
# diff with alg. 6: max=0.15493713538416176 min=0.0 std=0.024637496259428862 avg=0.011586586315265745
# diff with alg. 7: max=0.005073972284873052 min=0.0 std=0.0006306791513843534 avg=0.00021952839054565032
# diff with alg. 8: max=0.07664030266749122 min=1.3559875444713043e-10 std=0.012058886314850394 avg=0.005683791788136298
# diff with alg. 9: max=0.9859112237228443 min=0.0009178922743937057 std=0.18257891908565888 avg=0.885394792384028
# diff with alg. 10: max=0.1984145419080603 min=0.00034641521227329886 std=0.04997153543018332 avg=0.07293254921195871
# diff with alg. 11: max=0.30568499605245314 min=0.000526193974603073 std=0.06019313268823146 avg=0.047525969588586306
# diff with alg. 12: max=0.9859112234516471 min=0.00047826383064564215 std=0.18504432942423027 avg=0.8813545090055994
# diff with alg. 13: max=0.07664102564767228 min=1.3683976174405643e-10 std=0.012058903743526604 avg=0.00568389189506592
# -----------
#
# difference of algorithm=2 at horizon=7
# diff with alg. 0: max=0.07829610973648948 min=0.0 std=0.012580966423502121 avg=0.005903053601253555
# diff with alg. 1: max=0.07664102564767228 min=1.3683976174405643e-10 std=0.012058903743526604 avg=0.00568389189506592
# diff with alg. 2: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 3: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 4: max=0.07417727641870342 min=2.7367930144350794e-10 std=0.011918448769906548 avg=0.005614305282513654
# diff with alg. 5: max=0.0782975556968516 min=0.0 std=0.012581047303737398 avg=0.005903150744204593
# diff with alg. 6: max=0.07829610973648948 min=0.0 std=0.012580966423502121 avg=0.005903053601253555
# diff with alg. 7: max=0.0782975556968516 min=0.0 std=0.012581047303737398 avg=0.005903150744204593
# diff with alg. 8: max=9.929563618005233e-07 min=0.0 std=4.561267527786047e-07 avg=6.042187344348606e-07
# diff with alg. 9: max=0.9859122168148049 min=0.000903237709960425 std=0.18290791780623675 avg=0.887327855168934
# diff with alg. 10: max=0.24081980969688643 min=0.00033126295880336887 std=0.05535058863585318 avg=0.07546303216649948
# diff with alg. 11: max=0.2508434555834579 min=0.000675985785711597 std=0.05399926046004901 avg=0.04609225993697565
# diff with alg. 12: max=0.9859122165436076 min=0.0004636092662123614 std=0.18340244371109074 avg=0.8832875717905055
# diff with alg. 13: max=0.0 min=0.0 std=0.0 avg=0.0
# -----------
#
# difference of algorithm=3 at horizon=7
# diff with alg. 0: max=0.07829610973648948 min=0.0 std=0.012580966423502121 avg=0.005903053601253555
# diff with alg. 1: max=0.07664102564767228 min=1.3683976174405643e-10 std=0.012058903743526604 avg=0.00568389189506592
# diff with alg. 2: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 3: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 4: max=0.07417727641870342 min=2.7367930144350794e-10 std=0.011918448769906548 avg=0.005614305282513654
# diff with alg. 5: max=0.0782975556968516 min=0.0 std=0.012581047303737398 avg=0.005903150744204593
# diff with alg. 6: max=0.07829610973648948 min=0.0 std=0.012580966423502121 avg=0.005903053601253555
# diff with alg. 7: max=0.0782975556968516 min=0.0 std=0.012581047303737398 avg=0.005903150744204593
# diff with alg. 8: max=9.929563618005233e-07 min=0.0 std=4.561267527786047e-07 avg=6.042187344348606e-07
# diff with alg. 9: max=0.9859122168148049 min=0.000903237709960425 std=0.18290791780623675 avg=0.887327855168934
# diff with alg. 10: max=0.24081980969688643 min=0.00033126295880336887 std=0.05535058863585318 avg=0.07546303216649948
# diff with alg. 11: max=0.2508434555834579 min=0.000675985785711597 std=0.05399926046004901 avg=0.04609225993697565
# diff with alg. 12: max=0.9859122165436076 min=0.0004636092662123614 std=0.18340244371109074 avg=0.8832875717905055
# diff with alg. 13: max=0.0 min=0.0 std=0.0 avg=0.0
# -----------
#
# difference of algorithm=4 at horizon=7
# diff with alg. 0: max=0.1524733861551929 min=0.0 std=0.02449659929754315 avg=0.011514054553013261
# diff with alg. 1: max=0.0033684539023393634 min=0.0 std=0.00037106335336643223 avg=0.00010576882479823037
# diff with alg. 2: max=0.07417727641870342 min=2.7367930144350794e-10 std=0.011918448769906548 avg=0.005614305282513654
# diff with alg. 3: max=0.07417727641870342 min=2.7367930144350794e-10 std=0.011918448769906548 avg=0.005614305282513654
# diff with alg. 4: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 5: max=0.005417838900130922 min=0.0 std=0.0008070101869992203 avg=0.0002920590325790785
# diff with alg. 6: max=0.1524733861551929 min=0.0 std=0.02449659929754315 avg=0.011514054553013261
# diff with alg. 7: max=0.005417838900130922 min=0.0 std=0.0008070101869992203 avg=0.0002920590325790785
# diff with alg. 8: max=0.07417655343852236 min=1.3559864342482797e-10 std=0.011918436553132062 avg=0.005614197929470514
# diff with alg. 9: max=0.9859112239940417 min=0.0009178922743937057 std=0.1825036963862893 avg=0.8854192056630866
# diff with alg. 10: max=0.1988576182248556 min=0.00034641521227329886 std=0.04998319391150636 avg=0.07295785863819304
# diff with alg. 11: max=0.3056024515697826 min=0.0005346067866263127 std=0.06012858057171009 avg=0.04747062462565165
# diff with alg. 12: max=0.9859112237228445 min=0.00047826383064564215 std=0.18494661293295164 avg=0.8813789222846582
# diff with alg. 13: max=0.07417727641870342 min=2.7367930144350794e-10 std=0.011918448769906548 avg=0.005614305282513654
# -----------
#
# difference of algorithm=5 at horizon=7
# diff with alg. 0: max=0.15659366543334108 min=0.0 std=0.02516205788848186 avg=0.011806110129786333
# diff with alg. 1: max=0.005073972284873052 min=0.0 std=0.0006306791513843534 avg=0.00021952839054565032
# diff with alg. 2: max=0.0782975556968516 min=0.0 std=0.012581047303737398 avg=0.005903150744204593
# diff with alg. 3: max=0.0782975556968516 min=0.0 std=0.012581047303737398 avg=0.005903150744204593
# diff with alg. 4: max=0.005417838900130922 min=0.0 std=0.0008070101869992203 avg=0.0002920590325790785
# diff with alg. 5: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 6: max=0.15659366543334108 min=0.0 std=0.02516205788848186 avg=0.011806110129786333
# diff with alg. 7: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 8: max=0.07829683271667054 min=0.0 std=0.012581028944240931 avg=0.005903055064893166
# diff with alg. 9: max=0.9859112237228443 min=0.000683423488086421 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 10: max=0.19777496580738363 min=0.00011194642596601412 std=0.04979262996570206 avg=0.07283001323476271
# diff with alg. 11: max=0.3073579287528482 min=0.0004840649234200134 std=0.060424743090235475 avg=0.0476576376085538
# diff with alg. 12: max=0.9859112234516471 min=0.00024379504433835741 std=0.18518682129630304 avg=0.8812673807889534
# diff with alg. 13: max=0.0782975556968516 min=0.0 std=0.012581047303737398 avg=0.005903150744204593
# -----------
#
# difference of algorithm=6 at horizon=7
# diff with alg. 0: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 1: max=0.15493713538416176 min=0.0 std=0.024637496259428862 avg=0.011586586315265745
# diff with alg. 2: max=0.07829610973648948 min=0.0 std=0.012580966423502121 avg=0.005903053601253555
# diff with alg. 3: max=0.07829610973648948 min=0.0 std=0.012580966423502121 avg=0.005903053601253555
# diff with alg. 4: max=0.1524733861551929 min=0.0 std=0.02449659929754315 avg=0.011514054553013261
# diff with alg. 5: max=0.15659366543334108 min=0.0 std=0.02516205788848186 avg=0.011806110129786333
# diff with alg. 6: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 7: max=0.15659366543334108 min=0.0 std=0.02516205788848186 avg=0.011806110129786333
# diff with alg. 8: max=0.07829683271667054 min=0.0 std=0.012581028944240928 avg=0.005903055064893167
# diff with alg. 9: max=0.9859112239940417 min=0.001123051931834429 std=0.18420600774350543 avg=0.8893479475458104
# diff with alg. 10: max=0.29214188047386014 min=0.0005515748697140221 std=0.062104293185226575 avg=0.07913599440243672
# diff with alg. 11: max=0.19554853172498599 min=0.00045607582262130464 std=0.0489515343690749 avg=0.04635139587352872
# diff with alg. 12: max=0.9859112237228445 min=0.0006834234880863654 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 13: max=0.07829610973648948 min=0.0 std=0.012580966423502121 avg=0.005903053601253555
# -----------
#
# difference of algorithm=7 at horizon=7
# diff with alg. 0: max=0.15659366543334108 min=0.0 std=0.02516205788848186 avg=0.011806110129786333
# diff with alg. 1: max=0.005073972284873052 min=0.0 std=0.0006306791513843534 avg=0.00021952839054565032
# diff with alg. 2: max=0.0782975556968516 min=0.0 std=0.012581047303737398 avg=0.005903150744204593
# diff with alg. 3: max=0.0782975556968516 min=0.0 std=0.012581047303737398 avg=0.005903150744204593
# diff with alg. 4: max=0.005417838900130922 min=0.0 std=0.0008070101869992203 avg=0.0002920590325790785
# diff with alg. 5: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 6: max=0.15659366543334108 min=0.0 std=0.02516205788848186 avg=0.011806110129786333
# diff with alg. 7: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 8: max=0.07829683271667054 min=0.0 std=0.012581028944240931 avg=0.005903055064893166
# diff with alg. 9: max=0.9859112237228443 min=0.000683423488086421 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 10: max=0.19777496580738363 min=0.00011194642596601412 std=0.04979262996570206 avg=0.07283001323476271
# diff with alg. 11: max=0.3073579287528482 min=0.0004840649234200134 std=0.060424743090235475 avg=0.0476576376085538
# diff with alg. 12: max=0.9859112234516471 min=0.00024379504433835741 std=0.18518682129630304 avg=0.8812673807889534
# diff with alg. 13: max=0.0782975556968516 min=0.0 std=0.012581047303737398 avg=0.005903150744204593
# -----------
#
# difference of algorithm=8 at horizon=7
# diff with alg. 0: max=0.07829683271667054 min=0.0 std=0.012581028944240928 avg=0.005903055064893167
# diff with alg. 1: max=0.07664030266749122 min=1.3559875444713043e-10 std=0.012058886314850394 avg=0.005683791788136298
# diff with alg. 2: max=9.929563618005233e-07 min=0.0 std=4.561267527786047e-07 avg=6.042187344348606e-07
# diff with alg. 3: max=9.929563618005233e-07 min=0.0 std=4.561267527786047e-07 avg=6.042187344348606e-07
# diff with alg. 4: max=0.07417655343852236 min=1.3559864342482797e-10 std=0.011918436553132062 avg=0.005614197929470514
# diff with alg. 5: max=0.07829683271667054 min=0.0 std=0.012581028944240931 avg=0.005903055064893166
# diff with alg. 6: max=0.07829683271667054 min=0.0 std=0.012581028944240928 avg=0.005903055064893167
# diff with alg. 7: max=0.07829683271667054 min=0.0 std=0.012581028944240931 avg=0.005903055064893166
# diff with alg. 8: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 9: max=0.9859112238584431 min=0.000903237709960425 std=0.18290786624474642 avg=0.8873278058565961
# diff with alg. 10: max=0.2408206648584118 min=0.00033176064784001813 std=0.05535066340809462 avg=0.07546296142000317
# diff with alg. 11: max=0.2508443245023326 min=0.0006758902178726212 std=0.05399937410945086 avg=0.046092207102967284
# diff with alg. 12: max=0.9859112235872458 min=0.0004636092662123614 std=0.1834023998772107 avg=0.8832875224781677
# diff with alg. 13: max=9.929563618005233e-07 min=0.0 std=4.561267527786047e-07 avg=6.042187344348606e-07
# -----------
#
# difference of algorithm=9 at horizon=7
# diff with alg. 0: max=0.9859112239940417 min=0.001123051931834429 std=0.18420600774350543 avg=0.8893479475458104
# diff with alg. 1: max=0.9859112237228443 min=0.0009178922743937057 std=0.18257891908565888 avg=0.885394792384028
# diff with alg. 2: max=0.9859122168148049 min=0.000903237709960425 std=0.18290791780623675 avg=0.887327855168934
# diff with alg. 3: max=0.9859122168148049 min=0.000903237709960425 std=0.18290791780623675 avg=0.887327855168934
# diff with alg. 4: max=0.9859112239940417 min=0.0009178922743937057 std=0.1825036963862893 avg=0.8854192056630866
# diff with alg. 5: max=0.9859112237228443 min=0.000683423488086421 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 6: max=0.9859112239940417 min=0.001123051931834429 std=0.18420600774350543 avg=0.8893479475458104
# diff with alg. 7: max=0.9859112237228443 min=0.000683423488086421 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 8: max=0.9859112238584431 min=0.000903237709960425 std=0.18290786624474642 avg=0.8873278058565961
# diff with alg. 9: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 10: max=0.9754572721869326 min=0.0005714770621204068 std=0.1918196274696161 avg=0.8126467013648421
# diff with alg. 11: max=0.9794412279624873 min=0.001579223495672022 std=0.1994173513557237 avg=0.843108008076359
# diff with alg. 12: max=0.1565936654333411 min=0.0 std=0.02516205788848186 avg=0.011806110129786336
# diff with alg. 13: max=0.9859122168148049 min=0.000903237709960425 std=0.18290791780623675 avg=0.887327855168934
# -----------
#
# difference of algorithm=10 at horizon=7
# diff with alg. 0: max=0.29214188047386014 min=0.0005515748697140221 std=0.062104293185226575 avg=0.07913599440243672
# diff with alg. 1: max=0.1984145419080603 min=0.00034641521227329886 std=0.04997153543018332 avg=0.07293254921195871
# diff with alg. 2: max=0.24081980969688643 min=0.00033126295880336887 std=0.05535058863585318 avg=0.07546303216649948
# diff with alg. 3: max=0.24081980969688643 min=0.00033126295880336887 std=0.05535058863585318 avg=0.07546303216649948
# diff with alg. 4: max=0.1988576182248556 min=0.00034641521227329886 std=0.04998319391150636 avg=0.07295785863819304
# diff with alg. 5: max=0.19777496580738363 min=0.00011194642596601412 std=0.04979262996570206 avg=0.07283001323476271
# diff with alg. 6: max=0.29214188047386014 min=0.0005515748697140221 std=0.062104293185226575 avg=0.07913599440243672
# diff with alg. 7: max=0.19777496580738363 min=0.00011194642596601412 std=0.04979262996570206 avg=0.07283001323476271
# diff with alg. 8: max=0.2408206648584118 min=0.00033176064784001813 std=0.05535066340809462 avg=0.07546296142000317
# diff with alg. 9: max=0.9754572721869326 min=0.0005714770621204068 std=0.1918196274696161 avg=0.8126467013648421
# diff with alg. 10: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 11: max=0.2654989105353177 min=0.0 std=0.058605278786845225 avg=0.04871751663036493
# diff with alg. 12: max=0.9754757740864497 min=0.0001318486183723433 std=0.19674447538418238 avg=0.8086064179864136
# diff with alg. 13: max=0.24081980969688643 min=0.00033126295880336887 std=0.05535058863585318 avg=0.07546303216649948
# -----------
#
# difference of algorithm=11 at horizon=7
# diff with alg. 0: max=0.19554853172498599 min=0.00045607582262130464 std=0.0489515343690749 avg=0.04635139587352872
# diff with alg. 1: max=0.30568499605245314 min=0.000526193974603073 std=0.06019313268823146 avg=0.047525969588586306
# diff with alg. 2: max=0.2508434555834579 min=0.000675985785711597 std=0.05399926046004901 avg=0.04609225993697565
# diff with alg. 3: max=0.2508434555834579 min=0.000675985785711597 std=0.05399926046004901 avg=0.04609225993697565
# diff with alg. 4: max=0.3056024515697826 min=0.0005346067866263127 std=0.06012858057171009 avg=0.04747062462565165
# diff with alg. 5: max=0.3073579287528482 min=0.0004840649234200134 std=0.060424743090235475 avg=0.0476576376085538
# diff with alg. 6: max=0.19554853172498599 min=0.00045607582262130464 std=0.0489515343690749 avg=0.04635139587352872
# diff with alg. 7: max=0.3073579287528482 min=0.0004840649234200134 std=0.060424743090235475 avg=0.0476576376085538
# diff with alg. 8: max=0.2508443245023326 min=0.0006758902178726212 std=0.05399937410945086 avg=0.046092207102967284
# diff with alg. 9: max=0.9794412279624873 min=0.001579223495672022 std=0.1994173513557237 avg=0.843108008076359
# diff with alg. 10: max=0.2654989105353177 min=0.0 std=0.058605278786845225 avg=0.04871751663036493
# diff with alg. 11: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 12: max=0.9793660124342278 min=0.0011395950519239584 std=0.19548252187055132 avg=0.8390677246979305
# diff with alg. 13: max=0.2508434555834579 min=0.000675985785711597 std=0.05399926046004901 avg=0.04609225993697565
# -----------
#
# difference of algorithm=12 at horizon=7
# diff with alg. 0: max=0.9859112237228445 min=0.0006834234880863654 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 1: max=0.9859112234516471 min=0.00047826383064564215 std=0.18504432942423027 avg=0.8813545090055994
# diff with alg. 2: max=0.9859122165436076 min=0.0004636092662123614 std=0.18340244371109074 avg=0.8832875717905055
# diff with alg. 3: max=0.9859122165436076 min=0.0004636092662123614 std=0.18340244371109074 avg=0.8832875717905055
# diff with alg. 4: max=0.9859112237228445 min=0.00047826383064564215 std=0.18494661293295164 avg=0.8813789222846582
# diff with alg. 5: max=0.9859112234516471 min=0.00024379504433835741 std=0.18518682129630304 avg=0.8812673807889534
# diff with alg. 6: max=0.9859112237228445 min=0.0006834234880863654 std=0.1826384858990916 avg=0.8853076641673818
# diff with alg. 7: max=0.9859112234516471 min=0.00024379504433835741 std=0.18518682129630304 avg=0.8812673807889534
# diff with alg. 8: max=0.9859112235872458 min=0.0004636092662123614 std=0.1834023998772107 avg=0.8832875224781677
# diff with alg. 9: max=0.1565936654333411 min=0.0 std=0.02516205788848186 avg=0.011806110129786336
# diff with alg. 10: max=0.9754757740864497 min=0.0001318486183723433 std=0.19674447538418238 avg=0.8086064179864136
# diff with alg. 11: max=0.9793660124342278 min=0.0011395950519239584 std=0.19548252187055132 avg=0.8390677246979305
# diff with alg. 12: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 13: max=0.9859122165436076 min=0.0004636092662123614 std=0.18340244371109074 avg=0.8832875717905055
# -----------
#
# difference of algorithm=13 at horizon=7
# diff with alg. 0: max=0.07829610973648948 min=0.0 std=0.012580966423502121 avg=0.005903053601253555
# diff with alg. 1: max=0.07664102564767228 min=1.3683976174405643e-10 std=0.012058903743526604 avg=0.00568389189506592
# diff with alg. 2: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 3: max=0.0 min=0.0 std=0.0 avg=0.0
# diff with alg. 4: max=0.07417727641870342 min=2.7367930144350794e-10 std=0.011918448769906548 avg=0.005614305282513654
# diff with alg. 5: max=0.0782975556968516 min=0.0 std=0.012581047303737398 avg=0.005903150744204593
# diff with alg. 6: max=0.07829610973648948 min=0.0 std=0.012580966423502121 avg=0.005903053601253555
# diff with alg. 7: max=0.0782975556968516 min=0.0 std=0.012581047303737398 avg=0.005903150744204593
# diff with alg. 8: max=9.929563618005233e-07 min=0.0 std=4.561267527786047e-07 avg=6.042187344348606e-07
# diff with alg. 9: max=0.9859122168148049 min=0.000903237709960425 std=0.18290791780623675 avg=0.887327855168934
# diff with alg. 10: max=0.24081980969688643 min=0.00033126295880336887 std=0.05535058863585318 avg=0.07546303216649948
# diff with alg. 11: max=0.2508434555834579 min=0.000675985785711597 std=0.05399926046004901 avg=0.04609225993697565
# diff with alg. 12: max=0.9859122165436076 min=0.0004636092662123614 std=0.18340244371109074 avg=0.8832875717905055
# diff with alg. 13: max=0.0 min=0.0 std=0.0 avg=0.0
# -----------

# %%
df7.loc[df7["program"] == 6, "program"] = 0

df7.loc[df7["program"] == 4, "program"] = 1
df7.loc[df7["program"] == 5, "program"] = 1
df7.loc[df7["program"] == 7, "program"] = 1

df7.loc[df7["program"] == 3, "program"] = 2
df7.loc[df7["program"] == 8, "program"] = 2
df7.loc[df7["program"] == 13, "program"] = 2

# %%
result = get_df_horizon_describe(df7)
result.to_csv(DIR_PREFIX + "analysis_results/h7_programs.csv")
result
# Out:
#                           value                                        \
#                           count      mean       std     min       25%
# program variable
# 0       accum_prob        167.0  0.956243  0.049802  0.6195  0.946500
#         couplers_success  167.0  0.974862  0.018507  0.8920  0.967000
#         success0          167.0  0.974551  0.038404  0.6240  0.974500
#         success1          167.0  0.937934  0.070041  0.5010  0.923500
#         success_diff      167.0  0.036617  0.053295  0.0000  0.009000
# 1       accum_prob         42.0  0.920738  0.081079  0.7255  0.897875
#         couplers_success   42.0  0.979381  0.017314  0.9225  0.974375
#         success0           42.0  0.900095  0.107715  0.6850  0.862000
#         success1           42.0  0.941381  0.062480  0.7660  0.909000
#         success_diff       42.0 -0.041286  0.068682 -0.2380 -0.066500
# 2       accum_prob          8.0  0.947625  0.075352  0.7940  0.955000
#         couplers_success    8.0  0.979812  0.019274  0.9345  0.979875
#         success0            8.0  0.947625  0.075352  0.7940  0.955000
#         success1            8.0  0.947625  0.075352  0.7940  0.955000
#         success_diff        8.0  0.000000  0.000000  0.0000  0.000000
# 9       accum_prob          2.0  0.777750  0.237234  0.6100  0.693875
#         couplers_success    2.0  0.479000  0.002828  0.4770  0.478000
#         success0            2.0  0.878000  0.096167  0.8100  0.844000
#         success1            2.0  0.677500  0.378302  0.4100  0.543750
#         success_diff        2.0  0.200500  0.282136  0.0010  0.100750
# 10      accum_prob          1.0  0.611000       NaN  0.6110  0.611000
#         couplers_success    1.0  0.969500       NaN  0.9695  0.969500
#         success0            1.0  0.352000       NaN  0.3520  0.352000
#         success1            1.0  0.870000       NaN  0.8700  0.870000
#         success_diff        1.0 -0.518000       NaN -0.5180 -0.518000
# 11      accum_prob          3.0  0.596833  0.000577  0.5965  0.596500
#         couplers_success    3.0  0.315667  0.546751  0.0000  0.000000
#         success0            3.0  0.907333  0.046188  0.8540  0.894000
#         success1            3.0  0.286333  0.047343  0.2590  0.259000
#         success_diff        3.0  0.621000  0.093531  0.5130  0.594000
# 12      accum_prob          2.0  0.857500  0.144957  0.7550  0.806250
#         couplers_success    2.0  0.473250  0.023688  0.4565  0.464875
#         success0            2.0  0.827000  0.152735  0.7190  0.773000
#         success1            2.0  0.888000  0.137179  0.7910  0.839500
#         success_diff        2.0 -0.061000  0.015556 -0.0720 -0.066500
#
#
#                               50%       75%     max
# program variable
# 0       accum_prob        0.97150  0.984500  0.9970
#         couplers_success  0.98100  0.988000  0.9930
#         success0          0.98800  0.994000  0.9980
#         success1          0.96000  0.976500  0.9960
#         success_diff      0.02000  0.040000  0.4130
# 1       accum_prob        0.95700  0.983000  0.9945
#         couplers_success  0.98775  0.990375  0.9940
#         success0          0.95350  0.982250  0.9940
#         success1          0.96650  0.984500  0.9950
#         success_diff     -0.00350  0.000000  0.0000
# 2       accum_prob        0.98600  0.987250  0.9900
#         couplers_success  0.98650  0.990125  0.9940
#         success0          0.98600  0.987250  0.9900
#         success1          0.98600  0.987250  0.9900
#         success_diff      0.00000  0.000000  0.0000
# 9       accum_prob        0.77775  0.861625  0.9455
#         couplers_success  0.47900  0.480000  0.4810
#         success0          0.87800  0.912000  0.9460
#         success1          0.67750  0.811250  0.9450
#         success_diff      0.20050  0.300250  0.4000
# 10      accum_prob        0.61100  0.611000  0.6110
#         couplers_success  0.96950  0.969500  0.9695
#         success0          0.35200  0.352000  0.3520
#         success1          0.87000  0.870000  0.8700
#         success_diff     -0.51800 -0.518000 -0.5180
# 11      accum_prob        0.59650  0.597000  0.5975
#         couplers_success  0.00000  0.473500  0.9470
#         success0          0.93400  0.934000  0.9340
#         success1          0.25900  0.300000  0.3410
#         success_diff      0.67500  0.675000  0.6750
# 12      accum_prob        0.85750  0.908750  0.9600
#         couplers_success  0.47325  0.481625  0.4900
#         success0          0.82700  0.881000  0.9350
#         success1          0.88800  0.936500  0.9850
#         success_diff     -0.06100 -0.055500 -0.0500

# %% [markdown]
# # Visualizing Lambdas

# %%
df = pd.read_csv(DIR_PREFIX + "analysis_results/all_lambdas.csv")

# %%
df['hardware'] = df.apply(lambda row : row.hardware_spec + str(row.embedding) , axis=1)

# %%
df
# Out:
#      Unnamed: 0    hardware_spec  embedding  horizon    lambda  time  \
# 0             0      fake_athens          0        4  0.975781    33
# 1             1      fake_athens          0        5  0.981776   164
# 2             2      fake_athens          0        6  0.986671   802
# 3             3      fake_athens          0        7  0.987085  3896
# 4             4      fake_athens          1        4  0.954194    33
# ..          ...              ...        ...      ...       ...   ...
# 895         895  fake_washington          5        7  0.809437  4371
# 896         896  fake_washington          6        4  0.980529    37
# 897         897  fake_washington          6        5  0.981298   182
# 898         898  fake_washington          6        6  0.983211   899
# 899         899  fake_washington          6        7  0.983223  4401
#
#              hardware
# 0        fake_athens0
# 1        fake_athens0
# 2        fake_athens0
# 3        fake_athens0
# 4        fake_athens1
# ..                ...
# 895  fake_washington5
# 896  fake_washington6
# 897  fake_washington6
# 898  fake_washington6
# 899  fake_washington6
#
# [900 rows x 7 columns]

# %%
sns.set(rc={'figure.figsize':(20,5)})
sns.set_theme(style="whitegrid", font_scale=3)
palette="black"
ax = sns.catplot(kind="bar", height=10, aspect=.6, data=df.loc[df.hardware.isin(["fake_paris0", "fake_tenerife0", "fake_yorktown5", "fake_quito0", "fake_melbourne3"])], col="hardware", y="lambda", x="horizon", palette=["#757575", "#757575", "#757575", "#757575"])

# ax.bar_label(ax.containers[0], fontsize=10)
# ax.bar_label(ax.containers[1], fontsize=10)
# ax.bar_label(ax.containers[2], fontsize=10)
# ax.bar_label(ax.containers[3], fontsize=10)
# plt.legend(loc='lower right')

ax.set_titles("")
ax.set_axis_labels("horizon", "accuracy")
plt.savefig(DIR_PREFIX+"analysis_results/growth_per_horizon.pdf", format='pdf')

# %% [markdown]
# - fake_tenerife0: it is not worthy using the algorithm found at horizon=7, the advantage is in horizon=6. There is an increase only at even horizon
# - fake_yorktown5: the biggest advantage is at horizon=5
# - fake_quito0: might not be worthy to use algorithms found at horizon=6 and horizon=7
# - fake_melbourne3: there is an increase only at odd horizons
# - fake_paris0: might be worthy to explore further horizons

# %% [markdown]
# # Which kind of programs have the most advantage with respect to the traditional algorithm?

# %%
accs_diffs, diff_backends_stats = get_stats(4, comments, algs_union)
for (alg_index, values) in accs_diffs.items():
    print(f"{alg_index} -> max={max(values)}, {np.average(values)}")
# Out:
# 0 -> max=0.0, 0.0
# 1 -> max=0.05996622940671287, 0.04040512628868065

# %%
accs_diffs, diff_backends_stats = get_stats(4, comments, algs_union, get_trad_best=True)
for (alg_index, values) in accs_diffs.items():
    print(f"{alg_index} ({len(values)}) -> max={max(values)}, {np.average(values)}")
get_best_backends(accs_diffs, diff_backends_stats)
# Out:
# 0 (221) -> max=0.0, 0.0
# 1 (4) -> max=0.05996622940671287, 0.04040512628868065
# algorithms:  [1]
# fake_manhattan1

# %%
accs_diffs, diff_backends_stats = get_stats(5, comments, algs_union)
for (alg_index, values) in accs_diffs.items():
    if len(values) > 0:
        print(f"{alg_index} -> max={max(values)}, avg={np.average(values)}")
get_best_backends(accs_diffs, diff_backends_stats)
# Out:
# 0 -> max=0.0, avg=0.0
# 1 -> max=0.14638190973007836, avg=0.027148078055835734
# 2 -> max=9.79003475509721e-07, avg=6.878188386211237e-07
# 6 -> max=0.05695725177820676, avg=0.038224835585502714
# 7 -> max=0.05996622940671281, avg=0.04537576867964979
# algorithms:  [1]
# fake_johannesburg0

# %%
accs_diffs, diff_backends_stats = get_stats(6, comments, algs_union)
for (alg_index, values) in accs_diffs.items():
    if len(values) > 0:
        print(f"{alg_index} -> max={max(values)}, avg={np.average(values)}")
get_best_backends(accs_diffs, diff_backends_stats)
# Out:
# 0 -> max=0.0, avg=0.0
# 2 -> max=0.07340972255709144, avg=0.023787739759368487
# 3 -> max=0.06927627623076127, avg=0.02660338463395312
# 5 -> max=0.018920873809888383, avg=0.018920873809888383
# 6 -> max=0.06435388008301263, avg=0.056368694686235656
# algorithms:  [2]
# fake_yorktown5

# %%
accs_diffs, diff_backends_stats = get_stats(6, comments, algs_union, get_trad_best=True)
for (alg_index, values) in accs_diffs.items():
    if len(values) > 0:
        print(f"{alg_index} ({len(values)}) -> max={max(values)}, avg={np.average(values)}")
get_best_backends(accs_diffs, diff_backends_stats)
# Out:
# 0 (207) -> max=0.0, avg=0.0
# 2 (10) -> max=0.024469907519030554, avg=0.007929246586456162
# 3 (4) -> max=0.06927627623076127, avg=0.02660338463395312
# 5 (1) -> max=0.017279333633880567, avg=0.017279333633880567
# 6 (3) -> max=0.06068490500395962, avg=0.051941515204828516
# algorithms:  [3]
# fake_cambridge2

# %%
accs_diffs, diff_backends_stats = get_stats(7, comments, algs_union)
for (alg_index, values) in accs_diffs.items():
    if len(values) > 0:
        print(f"{alg_index} -> max={max(values)}, avg={np.average(values)}")
get_best_backends(accs_diffs, diff_backends_stats)
# Out:
# 0 -> max=0.0, avg=0.0
# 1 -> max=0.1130272085010311, avg=0.01810790611118686
# 2 -> max=9.928207631570984e-07, avg=7.1465655983316e-07
# 9 -> max=0.06281814381593864, avg=0.04331866169383514
# 10 -> max=0.1290434656489826, avg=0.1290434656489826
# 11 -> max=0.01162659807224209, avg=0.004179615152900329
# 12 -> max=0.06435388008301252, avg=0.053145734746069956
# algorithms:  [10]
# fake_cambridge2

# %%
accs_diffs, diff_backends_stats = get_stats(7, comments, algs_union, get_trad_best=True)
for (alg_index, values) in accs_diffs.items():
    if len(values) > 0:
        print(f"{alg_index} ({len(values)}) -> max={max(values)}, avg={np.average(values)}")
get_best_backends(accs_diffs, diff_backends_stats)
# Out:
# 0 (167) -> max=0.0, avg=0.0
# 1 (42) -> max=0.05651360425051555, avg=0.009053955302517897
# 2 (8) -> max=9.928207631570984e-07, avg=7.1465655983316e-07
# 9 (2) -> max=0.05988197745110985, avg=0.03937657279577331
# 10 (1) -> max=0.07403081963703129, avg=0.07403081963703129
# 11 (3) -> max=0.01162659807224209, avg=0.004076421545948857
# 12 (2) -> max=0.06101942466891863, avg=0.04874675304777751
# algorithms:  [10]
# fake_cambridge2

# %% [markdown]
# # Plots for Main Paper

# %%
from matplotlib.colors import to_rgba
TRAD_COLOR = "#1E4CF3"
TRAD_COLOR_W_ALPHA = to_rgba("#1E4CF3", 0.1)
IPMA1_COLOR = "#970E53"
IPMA2_COLOR = "#017100"
ORANGE = sns.color_palette()[1]
RED = "#ED220D"
BROWN = sns.color_palette()[5]
BLUEGREEN = "#00A89D"

# %%
TAKE_BEST = True
df_traditional = get_traditional_df(take_best=TAKE_BEST)
df_best4 = get_df_plots({4:1, 5:7, 6: 7}, take_best=TAKE_BEST) # get_chosen_algorithm_df(4,1, take_best=TAKE_BEST)
df_best6 = get_df_plots({4:0, 5:3, 6: 3}, take_best=TAKE_BEST)

# %%
df_best6
# Out:
#    hardware_spec   hardware  horizon  accuracy
# 0     Cambridge2  Cambridge        4  0.603756
# 1        Sydney2     Sydney        4  0.866810
# 2     Manhattan1  Manhattan        4  0.470015
# 3     Manhattan2  Manhattan        4  0.943313
# 4     Cambridge2  Cambridge        5  0.657501
# 5        Sydney2     Sydney        5  0.866810
# 6     Manhattan1  Manhattan        5  0.470015
# 7     Manhattan2  Manhattan        5  0.965124
# 8     Cambridge2  Cambridge        6  0.680593
# 9        Sydney2     Sydney        6  0.866810
# 10    Manhattan1  Manhattan        6  0.470015
# 11    Manhattan2  Manhattan        6  0.965124

# %%
df_traditional
# Out:
#    hardware_spec   hardware  horizon  accuracy
# 0     Cambridge2  Cambridge        4  0.603756
# 1        Sydney2     Sydney        4  0.866810
# 2     Manhattan1  Manhattan        4  0.470015
# 3     Manhattan2  Manhattan        4  0.943313
# 4     Cambridge2  Cambridge        5  0.603756
# 5        Sydney2     Sydney        5  0.881922
# 6     Manhattan1  Manhattan        5  0.471490
# 7     Manhattan2  Manhattan        5  0.943313
# 8     Cambridge2  Cambridge        6  0.611317
# 9        Sydney2     Sydney        6  0.942452
# 10    Manhattan1  Manhattan        6  0.471490
# 11    Manhattan2  Manhattan        6  0.975750

# %%
df_traditional['algorithm']  = 'Traditional'
df_best4['algorithm'] = 'Algorithm 1'
df_best6['algorithm'] = 'Algorithm 2'
all_dfs = pd.concat([df_traditional, df_best4, df_best6])

# %%
sns.set_theme(style="white", font_scale=1.5)
g = sns.catplot(
    all_dfs, kind="bar",
    col="hardware_spec", y="accuracy", x="horizon",
    height=5, aspect=.85, hue="algorithm",legend=False,palette=[TRAD_COLOR, IPMA1_COLOR, IPMA2_COLOR])
plt.ylim(0, 1.0)
# g.set(xticklabels=[])
# g.set(xlabel=None)
# g.set_titles(template='{col_name}')
# g.set_titles("")
# sns.move_legend(g, "center")
# g._legend.set_title("")

# g.despine(left=True)
# plt.legend(loc='upper right')

# iterate through axes
# for ax in g.axes.ravel():
    
#     # add annotations
#     for c in ax.containers:
#         labels = [f'{v.get_height()}' for v in c]
#         ax.bar_label(c, labels=labels, label_type='edge')
#     ax.margins(y=0.2)
g.refline(y=0.5, color='black', zorder=0)
g.refline(y=1.0, color='black', zorder=0)
#     ax.hlines([0.4], xmin="Traditional", xmax="Algorithm 2",  zorder=0)
#     ax.hlines([0.8],xmin="Sydney2", xmax="Cambridge2", zorder=0)
plt.savefig(DIR_PREFIX+"/analysis_results/all_hardwares.png", format='png')

# %% [markdown]
# # Visualizing all Lambdas

# %%
df, horizon_lines = get_df_visualizing_lambdas(comments, algs_union, only_own_alg=True, take_best=TAKE_BEST)
sns.set(rc={'figure.figsize':(20,30)},style="whitegrid",font_scale=2.5)

# %%
new_palette = [TRAD_COLOR, IPMA1_COLOR]
sns.stripplot(data=df[df.horizon == 4], x="accuracy", y="hardware", hue="alg_class", palette=new_palette,native_scale=True, orient="v", legend=False, s=15, alpha=0.7)
plt.savefig(DIR_PREFIX+"/images/h4_per_hardware_algs.pdf", format='pdf')

# %%
IPMA3_COLOR = "#B385ED"
new_palette = [TRAD_COLOR, IPMA2_COLOR, TRAD_COLOR, IPMA3_COLOR, IPMA1_COLOR]
# {4:0, 5:3, 6: 3}
hue_order = [0, 1, 2,6, 7]
assert len(new_palette) == len(hue_order)
sns.stripplot(data=df[df.horizon == 5], x="accuracy", y="hardware", hue="alg_class", palette=new_palette,native_scale=True, orient="v", legend=False, s=15, alpha=0.7,  hue_order=hue_order)
plt.savefig(DIR_PREFIX+"/images/h5_per_hardware_algs.pdf", format='pdf')

# %%
sns.set(rc={'figure.figsize':(18,30)},style="whitegrid",font_scale=2) # for main paper
IPMA4_COLOR = "#795548"
IPMA5_COLOR = "#B385ED"
new_palette = [TRAD_COLOR, IPMA2_COLOR,  IPMA4_COLOR, IPMA5_COLOR, IPMA1_COLOR]
hue_order = [0,3,2,5,6]
sns.stripplot(data=df[df.horizon == 6], x="accuracy", y="hardware", hue="alg_class", palette=new_palette,native_scale=True, orient="v", legend=False,  hue_order=hue_order, s=15, alpha=0.7)
plt.savefig(DIR_PREFIX+"/images/h6_per_hardware_algs.pdf", format='pdf')

# %%
IPMA6_COLOR = "#795548"
IPMA7_COLOR = "#F9DA56"
IPMA8_COLOR = "#B385ED"
new_palette = [TRAD_COLOR, IPMA2_COLOR,  IPMA6_COLOR, IPMA1_COLOR, IPMA7_COLOR, IPMA8_COLOR,TRAD_COLOR]
hue_order = [0,10,1,9,11,12,2]
assert len(new_palette) == len(hue_order)
sns.stripplot(data=df[df.horizon == 7], x="accuracy", y="hardware", hue="alg_class", palette=new_palette,native_scale=True, orient="v", legend=False,  hue_order=hue_order, s=15, alpha=0.7)
plt.savefig(DIR_PREFIX+"/images/h7_per_hardware_algs.pdf", format='pdf')

# %% [markdown]
# # Visualizing Accuracies

# %%
is_main = True # toggle 
TAKE_BEST = True
df, horizon_lines = get_df_visualizing_lambdas(comments, algs_union, filter_out_non_advantage=is_main, take_best=TAKE_BEST)
if is_main:
    sns.set(rc={'figure.figsize':(4,5)},style="white",font_scale=2) # for main paper
else:
    sns.set(rc={'figure.figsize':(15,10)},style="white",font_scale=1.5)
only_trad_df, _ = get_df_visualizing_lambdas(comments, algs_union, filter_out_non_advantage=False, take_best=TAKE_BEST, get_only_trad=True)

# %%
import random
import copy
if is_main:
    df2 = pd.concat([only_trad_df, df])    
else:
    df2 = df
hardware_order = copy.deepcopy(df2['hardware_spec'].values)
random.Random(1).shuffle(hardware_order)

# %%
new_palette = [TRAD_COLOR, IPMA1_COLOR, TRAD_COLOR_W_ALPHA]
hue_order = [0, 1, -1]

current_df = df2[df2.horizon==4]
for h in hardware_order:
    h_df= current_df[current_df.hardware_spec == h ]
    if h_df.shape[0] == 1:
        z_order = 1
    else:
        z_order = 3
    g = sns.scatterplot(data=h_df, x="hardware_spec", y="accuracy", hue="alg_class", style="program_type", legend=False, palette=new_palette,s=120, hue_order=hue_order, zorder=z_order)

for line in horizon_lines[4]:
    x = line[0]
    ymin = line[1]
    ymax = line[2]
    color = new_palette[line[3]]
    g.vlines([x], ymin, ymax, colors=color, zorder=2)

g.set(xticklabels=[])
g.set(xlabel="hardware specification")
# g.tick_params(bottom=True) 
plt.ylim(0.45, 1.0)

if is_main:
    plt.savefig(DIR_PREFIX+"/images/horizon4_main.pdf", format='pdf')
else:
    plt.savefig(DIR_PREFIX+"/images/horizon4.pdf", format='pdf')

# %%
# sns.set(rc={'figure.figsize':(5,7)},style="white",font_scale=2)
if is_main:
    OTHER_COLOR = "#EF8A3F"
    new_palette = [IPMA2_COLOR, TRAD_COLOR,  TRAD_COLOR, OTHER_COLOR, IPMA1_COLOR, TRAD_COLOR_W_ALPHA]
    hue_order = [1, 0, 2,6, 7, -1]
else:
    
    new_palette = [TRAD_COLOR, IPMA2_COLOR, TRAD_COLOR, IPMA3_COLOR, IPMA1_COLOR]
    hue_order = [0, 1, 2,6, 7]

# {4:0, 5:3, 6: 3}

current_df = df2[df2.horizon==5]
for h in hardware_order:
    h_df= current_df[current_df.hardware_spec == h ]
    if h_df.shape[0] == 1:
        z_order = 1
        g = sns.scatterplot(data=h_df, x="hardware_spec", y="accuracy", hue="alg_class", 
                            style="program_type", legend=False, palette=new_palette,s=120, 
                            hue_order=hue_order, zorder=z_order, style_order=["trad", "new"])
    else:
        z_order = 4
        g = sns.scatterplot(data=h_df[h_df.program_type == "new"], x="hardware_spec", y="accuracy", hue="alg_class", 
                            style="program_type", legend=False, palette=new_palette,s=120, 
                            hue_order=hue_order, zorder=z_order, style_order=["trad", "new"])
        z_order = 3
        g = sns.scatterplot(data=h_df[h_df.program_type == "trad"], x="hardware_spec", y="accuracy", hue="alg_class", 
                            style="program_type", legend=False, palette=new_palette,s=120, 
                            hue_order=hue_order, zorder=z_order, style_order=["trad", "new"])
g.set(xticklabels=[])
g.set(xlabel="hardware specification")
# g.tick_params(bottom=True) 

for line in horizon_lines[5]:
    x = line[0]
    ymin = line[1]
    ymax = line[2]
    color = get_color(line[3], hue_order, new_palette)
    if color ==  TRAD_COLOR:
        print(line)
    g.vlines([x], ymin, ymax, colors=color, zorder=2)
plt.ylim(0.45, 1.0)

if is_main:
    plt.savefig(DIR_PREFIX+"/images/horizon5_main.pdf", format='pdf')
else:
    plt.savefig(DIR_PREFIX+"/images/horizon5.pdf", format='pdf')
# Out:
# ('fake_perth2', 0.97565526416636, 0.976, 2)
# ('fake_cairo0', 0.9837574049574593, 0.984, 2)
# ('fake_geneva2', 0.9697737885104211, 0.97, 2)
# ('fake_washington0', 0.9686184942258939, 0.969, 2)

# %%
# # {4:0, 5:3, 6: 3}
if is_main:
    new_palette = [TRAD_COLOR, IPMA2_COLOR,  OTHER_COLOR, OTHER_COLOR, IPMA1_COLOR, TRAD_COLOR_W_ALPHA]
    hue_order = [0,3,2,5,6, -1]
else:
    new_palette = [TRAD_COLOR, IPMA2_COLOR,  IPMA4_COLOR, IPMA5_COLOR, IPMA1_COLOR]
    hue_order = [0,3,2,5,6]
sns.set_theme(style="white", font_scale=2)
current_df = df2[df2.horizon==6]
for h in hardware_order:
    h_df= current_df[current_df.hardware_spec == h ]
    if h_df.shape[0] == 1:
        z_order = 1
        g = sns.scatterplot(data=h_df, x="hardware_spec", y="accuracy", hue="alg_class", 
                            style="program_type", legend=False, palette=new_palette,s=120, 
                            hue_order=hue_order, zorder=z_order, style_order=["trad", "new"])
    else:
        z_order = 4
        g = sns.scatterplot(data=h_df[h_df.program_type == "new"], x="hardware_spec", y="accuracy", hue="alg_class", 
                            style="program_type", legend=False, palette=new_palette,s=120, 
                            hue_order=hue_order, zorder=z_order, style_order=["trad", "new"])
        z_order = 3
        g = sns.scatterplot(data=h_df[h_df.program_type == "trad"], x="hardware_spec", y="accuracy", hue="alg_class", 
                            style="program_type", legend=False, palette=new_palette,s=120, 
                            hue_order=hue_order, zorder=z_order, style_order=["trad", "new"])
g.set(xticklabels=[])
g.set(xlabel="hardware specification")
# g.tick_params(bottom=True) 

for line in horizon_lines[6]:
    x = line[0]
    ymin = line[1]
    ymax = line[2]
    color = get_color(line[3], hue_order, new_palette)
    g.vlines([x], ymin, ymax, colors=color, zorder=2)
    
plt.ylim(0.45, 1.0)
if is_main:
    plt.savefig(DIR_PREFIX+"/images/horizon6_I0_main.pdf", format='pdf')
else:
    plt.savefig(DIR_PREFIX+"/images/horizon6_I0.pdf", format='pdf')

# %%
# # {4:0, 5:3, 6: 3}
if is_main:
    new_palette = [TRAD_COLOR, IPMA2_COLOR, BROWN, ORANGE, BLUE_GREEN, IPMA1_COLOR, TRAD_COLOR_W_ALPHA]
    hue_order = [0,10,1,9,11,12, -1]
else:
    IPMA6_COLOR = "#795548"
    IPMA7_COLOR = "#F9DA56"
    IPMA8_COLOR = "#B385ED"
    new_palette = [TRAD_COLOR, IPMA2_COLOR,  IPMA6_COLOR, IPMA1_COLOR, IPMA7_COLOR, IPMA8_COLOR,TRAD_COLOR]
    hue_order = [0,10,1,9,11,12,2]
# sns.set_theme(style="white")
# sns.set(rc={'figure.figsize':(15,10)},style="white",font_scale=1.5)
g = sns.scatterplot(data=df2[df2.horizon == 7], legend=False, x="hardware_spec", y="accuracy", style="program_type", hue="alg_class", palette=new_palette, hue_order=hue_order, s=120)
g.set(xticklabels=[])
g.set(xlabel="hardware specification")
# g.tick_params(bottom=True)

plt.ylim(0.45, 1.0)
for line in horizon_lines[7]:
    x = line[0]
    ymin = line[1]
    ymax = line[2]
    color = get_color(line[3], hue_order, new_palette)
    g.vlines([x], ymin, ymax, colors=color)
# sns.set(rc={'figure.figsize':(12,10)})
plt.savefig(DIR_PREFIX+"/images/horizon7.pdf", format='pdf')

# %% [markdown]
# Note: For Main Paper figures build images call with `filter_out_non_advantage=True`

# %%
for horizon in range(4, 8):
    print("horizon: ", horizon)
    print(round(get_highest_advantage(horizon_lines[horizon])*100, 3))
    print()
# Out:
# horizon:  4
# 0.05998536470035648
# ('fake_manhattan1', 0.47001463529964355, 0.53, 1)
# 5.999
#
# horizon:  5
# 0.07273126664440221
# ('fake_johannesburg0', 0.8072687333555978, 0.88, 1)
# 7.273
#
# horizon:  6
# 0.0696830519500945
# ('fake_cambridge2', 0.6113169480499056, 0.681, 3)
# 6.968
#
# horizon:  7
# 0.0736830519500945
# ('fake_cambridge2', 0.6113169480499056, 0.685, 10)
# 7.368

# %%
0.6113169480499056 - 0.681
# Out:
# -0.0696830519500945

# %%
for horizon in range(4, 8):
    print("horizon: ", horizon)
    print(round(get_highest_advantage(horizon_lines[horizon])*100, 3))
    print()
# Out:
# horizon:  4
# 0.05998536470035648
# ('fake_manhattan1', 0.47001463529964355, 0.53, 1)
# 5.999
#
# horizon:  5
# 0.07273126664440221
# ('fake_johannesburg0', 0.8072687333555978, 0.88, 1)
# 7.273
#
# horizon:  6
# 0.0696830519500945
# ('fake_cambridge2', 0.6113169480499056, 0.681, 3)
# 6.968
#
# horizon:  7
# 0.0736830519500945
# ('fake_cambridge2', 0.6113169480499056, 0.685, 10)
# 7.368

# %%
-0.8072687333555978 +0.88
# Out:
# 0.07273126664440221

# %%
def get_average_advantage(lines):
    s = 0
    
    for line in lines:
        s += line[2] - line[1]
        
    return round(s/len(lines)*100, 3)

# %%
for horizon in range(4, 8):
    print(horizon, ":", get_average_advantage(horizon_lines[horizon]))
# Out:
# 4 : 3.4
# 5 : 2.964
# 6 : 2.692
# 7 : 3.326

# %%
for horizon in range(4,8):
    print(len(horizon_lines[horizon]))
# Out:
# 4
# 22
# 13
# 19

# %%
horizon_lines[5]
# Out:
# [('fake_oslo0', 0.9738583494806996, 0.974, 1),
#  ('fake_perth2', 0.97565526416636, 0.976, 2),
#  ('fake_perth4', 0.9656690545166945, 0.966, 1),
#  ('fake_melbourne3', 0.7791658973139998, 0.844, 1),
#  ('fake_tokyo6', 0.9182169767542007, 0.922, 1),
#  ('fake_tokyo7', 0.9215415723019474, 0.926, 1),
#  ('fake_johannesburg0', 0.8072687333555978, 0.88, 1),
#  ('fake_almaden4', 0.7438960041312067, 0.783, 1),
#  ('fake_almaden5', 0.7524817362025036, 0.793, 1),
#  ('fake_singapore0', 0.903890180330455, 0.941, 1),
#  ('fake_singapore1', 0.9069821951530324, 0.945, 1),
#  ('fake_singapore5', 0.9281160324726715, 0.929, 1),
#  ('fake_mumbai2', 0.945428649305681, 0.947, 1),
#  ('fake_mumbai3', 0.9492817774899358, 0.951, 1),
#  ('fake_mumbai4', 0.8932216184912951, 0.894, 1),
#  ('fake_mumbai5', 0.8935098943721903, 0.894, 1),
#  ('fake_mumbai7', 0.9585255452788465, 0.959, 1),
#  ('fake_paris0', 0.7780963791351435, 0.825, 1),
#  ('fake_paris4', 0.8775739400551519, 0.941, 1),
#  ('fake_auckland1', 0.9866512008010438, 0.987, 1),
#  ('fake_kolkata0', 0.9688053094724479, 0.97, 1),
#  ('fake_kolkata1', 0.9691332579969716, 0.971, 1),
#  ('fake_kolkata3', 0.9838330147763173, 0.984, 1),
#  ('fake_kolkata4', 0.987443337989011, 0.988, 1),
#  ('fake_toronto4', 0.7133793095616963, 0.731, 1),
#  ('fake_montreal0', 0.9775654444261893, 0.978, 1),
#  ('fake_montreal3', 0.8939181317560904, 0.895, 1),
#  ('fake_cairo0', 0.9837574049574593, 0.984, 2),
#  ('fake_cairo7', 0.9736014736165951, 0.981, 1),
#  ('fake_hanoi0', 0.9468764277013912, 0.956, 1),
#  ('fake_hanoi1', 0.9577641942245104, 0.967, 1),
#  ('fake_geneva0', 0.8425144225763783, 0.843, 1),
#  ('fake_geneva2', 0.9697737885104211, 0.97, 2),
#  ('fake_cambridge0', 0.49303842164342904, 0.51, 6),
#  ('fake_cambridge2', 0.6037561833487456, 0.658, 1),
#  ('fake_rochester0', 0.7415558000593754, 0.769, 1),
#  ('fake_manhattan0', 0.47152634445610947, 0.528, 6),
#  ('fake_manhattan1', 0.4714897850405467, 0.531, 7),
#  ('fake_manhattan2', 0.9433130526306696, 0.965, 1),
#  ('fake_washington0', 0.9686184942258939, 0.969, 2),
#  ('fake_washington1', 0.9738924836795853, 0.974, 1),
#  ('fake_washington4', 0.48570711692346175, 0.516, 7),
#  ('fake_washington5', 0.714711325427033, 0.73, 1)]

# %%
horizon_lines[7]
# Out:
# [('fake_oslo1', 0.9888922135125777, 0.989, 1),
#  ('fake_oslo2', 0.9887746053859191, 0.989, 2),
#  ('fake_oslo3', 0.9876252702036464, 0.988, 1),
#  ('fake_perth2', 0.9877688879450968, 0.988, 2),
#  ('fake_melbourne3', 0.8412151861786382, 0.895, 1),
#  ('fake_tokyo6', 0.9525744610564296, 0.954, 1),
#  ('fake_tokyo7', 0.9561720739995617, 0.957, 1),
#  ('fake_johannesburg0', 0.8689188747834775, 0.925, 1),
#  ('fake_almaden4', 0.8200360311030283, 0.86, 1),
#  ('fake_almaden5', 0.8313017070257659, 0.872, 1),
#  ('fake_singapore0', 0.9597943741647146, 0.976, 1),
#  ('fake_singapore1', 0.9633141595059442, 0.98, 1),
#  ('fake_mumbai3', 0.9871530404047018, 0.988, 1),
#  ('fake_mumbai4', 0.9647529583596061, 0.965, 1),
#  ('fake_mumbai5', 0.9650936748288638, 0.966, 1),
#  ('fake_paris0', 0.8589775483750006, 0.904, 1),
#  ('fake_paris4', 0.9311069975976706, 0.964, 1),
#  ('fake_auckland0', 0.9407695609643301, 0.941, 2),
#  ('fake_auckland1', 0.9928404856025403, 0.993, 1),
#  ('fake_kolkata1', 0.9885048306214717, 0.989, 1),
#  ('fake_kolkata4', 0.9925825790422996, 0.993, 1),
#  ('fake_toronto4', 0.7962682093956078, 0.817, 1),
#  ('fake_montreal3', 0.9627296534886285, 0.963, 1),
#  ('fake_cairo7', 0.9890915544236268, 0.99, 1),
#  ('fake_hanoi0', 0.9749617460818253, 0.977, 1),
#  ('fake_hanoi1', 0.9865338934391316, 0.988, 1),
#  ('fake_geneva0', 0.9256805763276235, 0.926, 1),
#  ('fake_geneva1', 0.9728372488312996, 0.973, 2),
#  ('fake_geneva2', 0.9825606584613936, 0.983, 2),
#  ('fake_cambridge0', 0.49303842164342904, 0.512, 9),
#  ('fake_cambridge2', 0.6113169480499056, 0.685, 10),
#  ('fake_rochester0', 0.8169117706738163, 0.844, 1),
#  ('fake_rochester4', 0.640760804905313, 0.652, 11),
#  ('fake_manhattan0', 0.47152634445610947, 0.531, 9),
#  ('fake_manhattan1', 0.4714897850405467, 0.533, 12),
#  ('fake_manhattan2', 0.9757498352000594, 0.981, 1),
#  ('fake_manhattan4', 0.500714295497282, 0.501, 11),
#  ('fake_manhattan5', 0.5007143403425447, 0.501, 11),
#  ('fake_washington4', 0.48570711692346175, 0.522, 12),
#  ('fake_washington5', 0.7924928656604843, 0.809, 1)]

# %%
0.6037561833487456 - 0.658
# Out:
# -0.05424381665125444

# %%
for line in horizon_lines[7]:
    current_advantage = line[2] - line[1]
    print(line[3],current_advantage)
# Out:
# 1 0.06400000000000006
# 1 0.051000000000000045
# 1 0.03300000000000003
# 1 0.04600000000000004
# 1 0.018000000000000016
# 1 0.02100000000000002
# 1 0.0050000000000000044
# 1 0.049000000000000044
# 1 0.03199999999999992
# 1 0.025000000000000022
# 9 0.02100000000000002
# 10 0.06600000000000006
# 1 0.031000000000000028
# 1 0.015000000000000013
# 11 0.015000000000000013
# 9 0.04700000000000004
# 12 0.04800000000000004
# 12 0.02100000000000002
# 1 0.02400000000000002

# %% [markdown]
# # Finding better examples for main paper

# %%
def get_trad_alg_indices(horizon):
    result = set()
    for (key, val) in algs_union[horizon].items():
        if val == 0:
            result.add(key)
    return result

# %%
# find hardware specifications whose best is the traditional algorithm in all horizons
trad_specs = set()

# add all hardware specs whose best is traditional algorithm at horizon 4
trad_specs = set(comments[4][0].split(","))
len(trad_specs)
for horizon in range(4,7):

    trad_algs_indices = get_trad_alg_indices(horizon)
    temp_trad_specs = set()
    for alg in trad_algs_indices:
        temp_trad_specs = temp_trad_specs.union(set(comments[horizon][alg].split(",")))
    trad_specs = trad_specs.intersection(temp_trad_specs)
        
len(trad_specs)
# Out:
# 160

# %%
df = pd.read_csv(DIR_PREFIX + "analysis_results/all_lambdas.csv")
df['hardware'] = df['hardware_spec'] +"-" +df['embedding'].astype(str)
df['model'] = df['hardware_spec'].str.replace('fake_','')
df = df[df['hardware'].isin(list(res.hardware_spec))]

# %%
sns.set(rc={'figure.figsize':(12,15)})
sns.set_theme(style="whitegrid", font_scale=1)
ax = sns.barplot(data=df[df.horizon < 7], y="hardware", x="lambda", hue="horizon")

# ax.bar_label(ax.containers[0], fontsize=10)
# ax.bar_label(ax.containers[1], fontsize=10)
# ax.bar_label(ax.containers[2], fontsize=10)
# ax.bar_label(ax.containers[3], fontsize=10)
# plt.legend(loc='lower right')

# ax.set_titles("")
# ax.set_axis_labels("horizon", "accuracy")
plt.savefig(DIR_PREFIX+"/images/all_good_trad.pdf", format='pdf')

# %%
def get_highest_difference_dataframe(keep_backends):
    f = open(DIR_PREFIX + "analysis_results/all_lambdas.csv")
    guarantees = dict() # map hardware spec -> horizon -> acc
    lines = f.readlines()[1:]
    for line in lines:
        elements = line.split(",")
        backend = elements[1] + "-" + str(elements[2]) 
        if backend in keep_backends:
            horizon = int(elements[3])
            guarantee = float(elements[4])

            if backend not in guarantees.keys():
                guarantees[backend] = dict()
            guarantees[backend][horizon] = guarantee
        
    backends = []
    diffs = []
    
    for (backend, results) in guarantees.items():
        backends.append(backend)
        diffs.append(results[6] - results[4])
    return pd.DataFrame.from_dict({
        'hardware_spec': backends,
        'diff4_6': diffs
    })

# %%
diffs46_df = get_highest_difference_dataframe(trad_specs2)

# %%
res = diffs46_df[diffs46_df.diff4_6 >=0.05].sort_values(by=['diff4_6'], ascending=False)
res
# Out:
#         hardware_spec   diff4_6
# 62      fake_sydney-3  0.076869
# 61      fake_sydney-2  0.075642
# 17    fake_yorktown-3  0.073128
# 16    fake_yorktown-2  0.070701
# 46       fake_tokyo-1  0.068730
# 48  fake_boeblingen-4  0.064081
# 47       fake_tokyo-2  0.063979
# 50  fake_boeblingen-6  0.059454
# 63       fake_hanoi-5  0.059193
# 49  fake_boeblingen-5  0.059192
# 55   fake_singapore-4  0.053876
# 54   fake_singapore-3  0.053624
# 59     fake_toronto-1  0.052394
# 64    fake_brooklyn-0  0.050592
# 58     fake_toronto-0  0.050583

# %% [markdown]
# # check backend_vs

# %%
lambdas = dict() # horizon->backend-> (lambda, sim_acc)
backend_to_own_algo = dict() # horizon -> backend -> algo_index
for i in range(4, 8):
    lambdas[i] = dict()
    backend_to_own_algo[i] = dict()

f = open(DIR_PREFIX + "analysis_results/test_lambdas.csv")

lines = f.readlines()[1:]

for line in lines:
    elements = line.split(",")
    backend = elements[0]
    temp = backend.split("-")
    horizon = int(elements[1])
    l = float(elements[2])
    sim_acc = float(elements[3])
    assert horizon in lambdas.keys()
    assert backend not in lambdas[horizon].keys()
    lambdas[horizon][f"{temp[0]}{temp[1]}"] = (l, sim_acc)
    assert abs(l-sim_acc) < 0.1
    backend_to_own_algo[horizon][f"{temp[0]}{temp[1]}"] = get_backend_algorithm(temp[0], horizon, temp[1], comments)
    
f.close()

f = open(DIR_PREFIX + "analysis_results/backends_vs.csv")
lines = f.readlines()[1:]

for line in lines:
    elements = line.split(",")
    horizon = int(elements[0])
    alg_index = int(elements[1])
    backend = elements[2]
    sim_acc = float(elements[3])
    if alg_index == backend_to_own_algo[horizon][backend]:
        l, sim_acc2 = lambdas[horizon][backend]
        if abs(sim_acc - l) >= 0.01 and abs(sim_acc - sim_acc2) >= 0.01:
            print(horizon, backend, alg_index, l, sim_acc2, sim_acc, round(sim_acc - l,3))
    

f.close()
# Out:
# 4 fake_tenerife1 0 0.7533080731324889 0.756 0.742 -0.011
# 4 fake_melbourne3 0 0.7791658973139998 0.783 0.767 -0.012
# 4 fake_tokyo2 0 0.7661269634640065 0.766 0.783 0.017
# 4 fake_johannesburg3 0 0.9385097308748754 0.941 0.927 -0.012
# 4 fake_almaden4 0 0.7438960041312067 0.735 0.755 0.011
# 4 fake_toronto4 0 0.7133793095616963 0.71 0.73 0.017
# 4 fake_rochester0 0 0.7415558000593754 0.746 0.724 -0.018
# 5 fake_poughkeepsie2 0 0.8546215694525122 0.856 0.869 0.014
# 5 fake_poughkeepsie4 0 0.8324375360041666 0.837 0.822 -0.01
# 5 fake_auckland0 2 0.8571062917809806 0.858 0.871 0.014
# 5 fake_manhattan4 0 0.500714295497282 0.515 0.483 -0.018
# 5 fake_manhattan5 0 0.5007143403425447 0.497 0.511 0.01
# 6 fake_paris4 3 0.9465224163018916 0.948 0.936 -0.011
# 6 fake_cambridge0 5 0.5103177552773096 0.507 0.521 0.011
# 6 fake_cambridge3 0 0.9300053068881836 0.933 0.92 -0.01
# 7 fake_kolkata2 0 0.9333971181055266 0.933 0.922 -0.011
# 7 fake_manhattan5 11 0.5010156975317548 0.49 0.525 0.024

# %%
lambdas = dict() # horizon->backend-> (lambda, sim_acc)
backend_to_own_algo = dict() # horizon -> backend -> algo_index
for i in range(4, 8):
    lambdas[i] = dict()
    backend_to_own_algo[i] = dict()

f = open(DIR_PREFIX + "analysis_results/test_lambdas.csv")

lines = f.readlines()[1:]

for line in lines:
    elements = line.split(",")
    backend = elements[0]
    temp = backend.split("-")
    horizon = int(elements[1])
    l = float(elements[2])
    sim_acc = float(elements[3])
    assert horizon in lambdas.keys()
    assert backend not in lambdas[horizon].keys()
    lambdas[horizon][f"{temp[0]}{temp[1]}"] = (l, sim_acc)
    assert abs(l-sim_acc) < 0.1
    backend_to_own_algo[horizon][f"{temp[0]}{temp[1]}"] = get_backend_algorithm(temp[0], horizon, temp[1], comments)
    
f.close()

f = open(DIR_PREFIX + "analysis_results/backends_vs_.csv")
lines = f.readlines()[1:]

for line in lines:
    elements = line.split(",")
    horizon = int(elements[0])
    alg_index = int(elements[1])
    backend = elements[2]
    sim_acc = float(elements[3])
    if alg_index == backend_to_own_algo[horizon][backend]:
        l, sim_acc2 = lambdas[horizon][backend]
        if abs(sim_acc - l) >= 0.01:
            print(horizon, backend, alg_index, l, sim_acc2, sim_acc, round(sim_acc - l,3))
    

f.close()
# Out:
# 4 fake_tokyo2 0 0.7661269634640065 0.766 0.755 -0.011
# 4 fake_manhattan1 1 0.5299808647063564 0.529 0.51 -0.02
# 5 fake_melbourne3 3 0.844155601808699 0.835 0.855 0.011
# 5 fake_tokyo2 0 0.8220136554435529 0.824 0.833 0.011
# 5 fake_poughkeepsie5 0 0.8402555151454438 0.835 0.851 0.011
# 5 fake_almaden5 3 0.7928790831505428 0.799 0.781 -0.012
# 5 fake_mumbai5 3 0.8942969591407606 0.89 0.905 0.011
# 5 fake_cambridge0 6 0.5097462096943993 0.519 0.493 -0.017
# 5 fake_rochester1 3 0.7692706456115302 0.771 0.781 0.012
# 5 fake_manhattan0 6 0.5284778758883534 0.538 0.54 0.012
# 6 fake_toronto4 0 0.7962682093956078 0.798 0.786 -0.01
# 6 fake_manhattan1 7 0.5321746900445063 0.522 0.548 0.016
# 6 fake_manhattan5 2 0.5009016546407954 0.497 0.512 0.011
# 7 fake_rochester1 5 0.858304829159687 0.857 0.874 0.016
# 7 fake_manhattan4 11 0.5010156048736764 0.503 0.513 0.012

# %%
alg
