# %%
from notebook_utils import *
import os, sys
sys.path.append(os.getcwd()+"/../problems")
import bitflip
experiment_id = BitflipExperimentID.IPMA2

# %%
embeddings = load_all_embeddings(BitflipExperimentID.IPMA2, False)
count = 0
for (hardware_spec, embeddings_dict) in embeddings.items():
    count += len(embeddings_dict.keys())
count
# Out:
# 225

# %%
find_similar_algorithms(experiment_id, 4, 7)
# Out:
# [h=4] 1 ~ 4 --> diff. = 0.0
# [h=6] 1 ~ 4 --> diff. = 0.0

# %% [markdown]
# # Characterizing Algorithms

# %%
diff_algs_to_spec = get_diff_algorithms_to_spec(experiment_id, bitflip.get_hardware_embeddings, bitflip.get_experiments_actions, with_thermalization=False)

# %%
all_summaries = []
for horizon in range(2, 8):
    all_summaries.append(get_summary_per_algo(experiment_id, bitflip.get_experiments_actions, horizon, diff_algs_to_spec, drop_columns=["oneq_gates"]))

# %%
file_path = os.path.join(get_project_path(), get_experiment_name_path(experiment_id), experiment_id.value, "horizon7_table.csv")
all_summaries[-1]
# .to_csv(file_path)
# Out:
#                           value                                            \
#                           count   mean    std    min    25%    50%    75%
# program variable
# 0       accum_prob        154.0  0.956  0.055  0.619  0.951  0.976  0.986
#         couplers_success  154.0  0.980  0.016  0.923  0.975  0.986  0.990
#         success0          154.0  0.961  0.058  0.624  0.954  0.984  0.990
#         success1          154.0  0.950  0.053  0.615  0.943  0.966  0.983
#         success_diff      154.0  0.011  0.020 -0.115  0.000  0.009  0.020
# 1       accum_prob         35.0  0.915  0.082  0.598  0.912  0.952  0.964
#         couplers_success   35.0  0.968  0.020  0.906  0.960  0.976  0.982
#         success0           35.0  0.974  0.031  0.854  0.968  0.987  0.991
#         success1           35.0  0.856  0.135  0.341  0.847  0.914  0.938
#         success_diff       35.0  0.118  0.107  0.030  0.052  0.077  0.137
# 2       accum_prob          5.0  0.967  0.025  0.923  0.974  0.978  0.978
#         couplers_success    5.0  0.953  0.028  0.911  0.938  0.965  0.973
#         success0            5.0  0.995  0.002  0.993  0.995  0.996  0.996
#         success1            5.0  0.939  0.048  0.853  0.952  0.960  0.960
#         success_diff        5.0  0.056  0.047  0.027  0.035  0.035  0.043
# 3       accum_prob         10.0  0.828  0.102  0.611  0.777  0.820  0.912
#         couplers_success   10.0  0.972  0.014  0.949  0.966  0.974  0.983
#         success0           10.0  0.734  0.162  0.352  0.694  0.706  0.856
#         success1           10.0  0.922  0.054  0.853  0.871  0.938  0.964
#         success_diff       10.0 -0.188  0.130 -0.518 -0.217 -0.164 -0.110
# 4       accum_prob          1.0  0.970    NaN  0.970  0.970  0.970  0.970
#         couplers_success    1.0  0.966    NaN  0.966  0.966  0.966  0.966
#         success0            1.0  0.994    NaN  0.994  0.994  0.994  0.994
#         success1            1.0  0.946    NaN  0.946  0.946  0.946  0.946
#         success_diff        1.0  0.048    NaN  0.048  0.048  0.048  0.048
# 5       accum_prob         10.0  0.989  0.004  0.983  0.987  0.989  0.992
#         couplers_success   10.0  0.968  0.014  0.935  0.964  0.969  0.980
#         success0           10.0  0.996  0.001  0.994  0.996  0.996  0.997
#         success1           10.0  0.981  0.006  0.972  0.978  0.982  0.987
#         success_diff       10.0  0.015  0.005  0.008  0.010  0.014  0.018
# 6       accum_prob          4.0  0.993  0.005  0.986  0.990  0.994  0.997
#         couplers_success    4.0  0.954  0.042  0.892  0.948  0.971  0.978
#         success0            4.0  0.994  0.005  0.988  0.992  0.996  0.998
#         success1            4.0  0.991  0.006  0.984  0.988  0.992  0.995
#         success_diff        4.0  0.003  0.001  0.002  0.003  0.003  0.003
# 7       accum_prob          2.0  0.850  0.135  0.755  0.803  0.850  0.898
#         couplers_success    2.0  0.718  0.018  0.706  0.712  0.718  0.725
#         success0            2.0  0.832  0.161  0.719  0.776  0.832  0.889
#         success1            2.0  0.868  0.109  0.791  0.830  0.868  0.906
#         success_diff        2.0 -0.036  0.051 -0.072 -0.054 -0.036 -0.018
# 8       accum_prob          1.0  0.960    NaN  0.960  0.960  0.960  0.960
#         couplers_success    1.0  0.740    NaN  0.740  0.740  0.740  0.740
#         success0            1.0  0.935    NaN  0.935  0.935  0.935  0.935
#         success1            1.0  0.985    NaN  0.985  0.985  0.985  0.985
#         success_diff        1.0 -0.049    NaN -0.049 -0.049 -0.049 -0.049
# 9       accum_prob          2.0  0.596  0.000  0.596  0.596  0.596  0.596
#         couplers_success    2.0  0.500  0.000  0.500  0.500  0.500  0.500
#         success0            2.0  0.934  0.000  0.934  0.934  0.934  0.934
#         success1            2.0  0.259  0.000  0.259  0.259  0.259  0.259
#         success_diff        2.0  0.675  0.000  0.675  0.675  0.675  0.675
# 10      accum_prob          1.0  0.610    NaN  0.610  0.610  0.610  0.610
#         couplers_success    1.0  0.727    NaN  0.727  0.727  0.727  0.727
#         success0            1.0  0.810    NaN  0.810  0.810  0.810  0.810
#         success1            1.0  0.410    NaN  0.410  0.410  0.410  0.410
#         success_diff        1.0  0.400    NaN  0.400  0.400  0.400  0.400
#
#
#                             max
# program variable
# 0       accum_prob        0.996
#         couplers_success  0.994
#         success0          0.997
#         success1          0.995
#         success_diff      0.061
# 1       accum_prob        0.979
#         couplers_success  0.990
#         success0          0.997
#         success1          0.964
#         success_diff      0.512
# 2       accum_prob        0.983
#         couplers_success  0.979
#         success0          0.997
#         success1          0.970
#         success_diff      0.140
# 3       accum_prob        0.960
#         couplers_success  0.988
#         success0          0.935
#         success1          0.985
#         success_diff     -0.049
# 4       accum_prob        0.970
#         couplers_success  0.966
#         success0          0.994
#         success1          0.946
#         success_diff      0.048
# 5       accum_prob        0.994
#         couplers_success  0.983
#         success0          0.998
#         success1          0.990
#         success_diff      0.022
# 6       accum_prob        0.997
#         couplers_success  0.984
#         success0          0.998
#         success1          0.996
#         success_diff      0.004
# 7       accum_prob        0.946
#         couplers_success  0.731
#         success0          0.946
#         success1          0.945
#         success_diff      0.000
# 8       accum_prob        0.960
#         couplers_success  0.740
#         success0          0.935
#         success1          0.985
#         success_diff     -0.049
# 9       accum_prob        0.596
#         couplers_success  0.500
#         success0          0.934
#         success1          0.259
#         success_diff      0.675
# 10      accum_prob        0.610
#         couplers_success  0.727
#         success0          0.810
#         success1          0.410
#         success_diff      0.400

# %% [markdown]
# The algorithms that have repeated blocks of CX gates are algorithms
# - 2:
#   - Max advantange 0.6%
#   - accum_prob (avg) = 0.967
#   - couplers_succes (avg) = 0.953
# - 4:
#   - max advantage 0.3%
#   - accum_prob (avg) = 0.970
#   - couplers_succes = 0.966
# - 5:
#   - max advantage 0.6%
#   - accum_prob (avg) = 0.989
#   - couplers_succes = 0.968
# - 6:
#   - max advantage 1.3%
#   - accum_prob (avg) = 0.993
#   - couplers_succes (avg) = 0.954
#
# success difference is at most 0.048
#
# accum_prob is the most distinctive attribute

# %% [markdown]
# # Plots

# %%
df, horizon_lines = get_df_visualizing_lambdas(experiment_id, diff_algs_to_spec)

# %%
from utils import get_index


def get_scatterplot_guarantees_compare(experiment_id, horizon, df, horizon_lines, horizon_to_num_algs, new_palette=None, hue_order=None):
    plt.clf()
    plt.figure(figsize=(15, 10))
    
    # Set Seaborn context
    sns.set(style="white", font_scale=1.5)

    if new_palette is None:
        new_palette = sns.color_palette(n_colors=horizon_to_num_algs[horizon]+1)
    if hue_order is None:
        hue_order = [x for x in range(0, horizon_to_num_algs[horizon]+1)]
    current_df = df[df.horizon==horizon]
    hardware_order = copy.deepcopy(df['hardware_spec'].values)
    for h in hardware_order:
        h_df = current_df[current_df.hardware_spec == h ]
        z_order = 4
        g = sns.scatterplot(data=h_df[h_df.algorithm_type == "new"], x="hardware_spec", y="accuracy", hue="alg_class", 
                            style="algorithm_type", legend=False, palette=new_palette,s=120, 
                            hue_order=hue_order, zorder=z_order, style_order=["trad", "new"])
        z_order = 3
        g = sns.scatterplot(data=h_df[h_df.algorithm_type == "trad"], x="hardware_spec", y="accuracy", hue="alg_class", 
                            style="algorithm_type", legend=False, palette=new_palette,s=120, 
                            hue_order=hue_order, zorder=z_order, style_order=["trad", "new"])

    if horizon in horizon_lines.keys():
        for line in horizon_lines[horizon]:
            x = line[0]
            ymin = line[1]
            ymax = line[2]
            color = new_palette[get_index(line[3], hue_order)]
            g.vlines([x], ymin, ymax, colors=color, zorder=2)

    g.set(xticklabels=[])
    g.set(xlabel="hardware specification")
    # plt.ylim(0.45, 1.0001)
    output_dir = os.path.join(get_project_path(), get_experiment_name_path(experiment_id), experiment_id.value)
    plt.savefig(os.path.join(output_dir, f"scatter_guarantees{horizon}.pdf"), format='pdf')
    return g

# %%
horizon_to_num_algs = get_dict_horizon_num_algs(experiment_id, 4, 7)
# for horizon in range(4, 8):
#     get_scatterplot_guarantees_compare(experiment_id, horizon, df, horizon_lines, horizon_to_num_algs)
TRAD_COLOR = "#1E4CF3"
IPMA1_COLOR = "#970E53"
IPMA2_COLOR = "#017100"
IPMA6_COLOR = "#795548"
IPMA7_COLOR = "#F9DA56"
IPMA8_COLOR = "#B385ED"
CYAN = "#00FFFF"
ORANGE = "#FF6A00"
TEAL = "#004D4D"
LIMEGREEN = "#A7F432"
new_palette = [TRAD_COLOR, IPMA6_COLOR, IPMA2_COLOR, IPMA7_COLOR,  IPMA8_COLOR, 
               CYAN, ORANGE, TEAL, IPMA1_COLOR, LIMEGREEN]
hue_order = [0, 2, 3, 4,5,6,  7,8, 9, 11]
get_scatterplot_guarantees_compare(experiment_id, 7, df, horizon_lines, horizon_to_num_algs, new_palette, hue_order)
# Out:
# <Axes: xlabel='hardware specification', ylabel='accuracy'>

# %%
get_best_algos_advantanges(experiment_id, diff_algs_to_spec)
# Out:
# {1: {},
#  2: {},
#  3: {1: 0.030000000000000027},
#  4: {3: 0.07299999999999995, 5: 0.028000000000000025, 6: 0.031000000000000028},
#  5: {1: 0.02400000000000002,
#   2: 0.07000000000000006,
#   3: 0.03200000000000003,
#   4: 0.010000000000000009},
#  6: {3: 0.05600000000000005,
#   5: 0.031000000000000028,
#   6: 0.03300000000000003,
#   8: 0.07400000000000007,
#   7: 0.01100000000000001},
#  7: {2: 0.006999999999999895,
#   1: 0.04799999999999993,
#   3: 0.09799999999999998,
#   4: 0.0030000000000000027,
#   5: 0.006000000000000005,
#   6: 0.013000000000000012,
#   7: 0.03200000000000003,
#   8: 0.03300000000000003,
#   10: 0.014000000000000012}}
