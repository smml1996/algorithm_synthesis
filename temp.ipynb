# %%
from ibm_noise_models import *

# %%
noise_model = get_ibm_noise_model(HardwareSpec.MANHATTAN)

# %%
noise_model.to_dict()
# Out:
# {'errors': [{'type': 'qerror',
#    'id': '552e6a371c264d548f3996a1544bcade',
#    'operations': ['id'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998236+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99966863+0.j]]),
#        array([[-0.00593908+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00594094+0.j]]),
#        array([[0.        +0.j, 0.02504676+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998236+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99966863+0.j]]),
#        array([[-0.00593908+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00594094+0.j]]),
#        array([[0.        +0.j, 0.02504676+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]},
# ...
