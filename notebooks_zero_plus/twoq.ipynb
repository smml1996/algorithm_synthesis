# %%
import os, sys
sys.path.append(os.getcwd() + "/../")
import notebook_utils
from experiments_utils import TwoQZeroPlusExperimentID

# %%
notebook_utils.find_similar_algorithms(TwoQZeroPlusExperimentID.TWOQ, 3, 5)
# Out:
# 0 4
# alg_index_ 0
# {0: 0.8462858818, 1: 0.8462858742, 2: 0.8462758972, 3: 0.6694546032}
# {0: 0.8470456622, 1: 0.84703871088696, 2: 0.847027202043276, 3: 0.6737047107}
# {0: 0.839282372, 1: 0.839292372, 2: 0.839272372, 3: 0.6540250594}
# {0: 0.844978353, 1: 0.844978353, 2: 0.8449883532, 3: 0.6581773628}
# {0: 0.8494891378, 1: 0.8494891378, 2: 0.8494991376, 3: 0.673385274}
# {0: 0.8468324144, 1: 0.84684932064768, 2: 0.846830882624144, 3: 0.4886330972}
# {0: 0.8477472992, 1: 0.84777425114592, 2: 0.847765776772992, 3: 0.6710183672}
# {0: 0.8477624578, 1: 0.847745502550844, 2: 0.847763979875424, 3: 0.48829356275}
# {0: 0.8448189866, 1: 0.8448189778, 2: 0.8448289692, 3: 0.6737146574}
# {0: 0.848681777, 1: 0.8486817734, 2: 0.8486717772, 3: 0.67381885895}
# {0: 0.839315897, 1: 0.839322686518008, 2: 0.839334290058968, 3: 0.6467962834}
# {0: 0.840704, 1: 0.84071082988032, 2: 0.84070240694, 3: 0.6451494534}
# {0: 0.8448678858, 1: 0.8448678858, 2: 0.844857896, 3: 0.6730017671}
# ...
